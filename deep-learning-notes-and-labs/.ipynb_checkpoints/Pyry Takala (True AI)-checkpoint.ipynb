# %% [markdown]
# # Pyry Takala (True AI)
#
# ## Self-learning conversation systems
#
# ### Deep learning in customer service
# * bc much data
#
# ### Problems
# * e.g. 6h delay response on Twitter
# * email convo different structure
# * repetitive convos
# * rule based systems fail in non-niche domains (& chatbots repetitive)
#     * q->a AIML templates (literals or rules)
#     * expr -> expr (e.g. \*, set name = ... )
#     * expr tree (IBM Watson) but still building by hand
#     * expr tree + ML module (intent recogniser, e.g. traffic_update, off_topic, weather -> pre-annotated or annotate your own)
#     * many 'tree & ML module -> tree' e.g. intent, entities, dialogue (// Siri, Alexa...)
#         * + annotated training data + maintenance
#
# ### True AI solutions
# * Automatic suggestions (3x) with confidence levels
# * human op still in control
#     * ? presumably it keeps track of what you choose and send
# * reply automatically for simple queries
#
# ### Tech
# * RNN, claimns 201x+
#     * History 1950+AI, 199x chess; 1990+ ML, c2010 IBM Watson, c2008+ DL, 201x+ RNN
#     * 2011: RNN hard to train
#     * ...LSTM with different gates uhhh ok so you can keep more memory in the NN okay makes sense for convos cause you should remember stuff
# * Attention (c2014+): where in convo to focus
# * Pipeline
#     * Read query (focus on key parts using neural attention)
#     * Understand meaning (intention, key meanings... <- not rules though)
#     * Sugest responses in human style <- haha
# * Training
#     * Phrase Vectors -> sim input vector give sim response
# * Tech
#     * Tensorflow, `dynamic_rnn`
# YES WILDML
# * Hoping to incorporate transfer learning
#     * problems: info leakage
#
# ### Model
# * NN with 1M-10M weights/parameters, info not in DB atm.
#     * Solved by academics but not really implemented yet
# *
#
# ### Pricing
# * per suggestion
# * flat fee
#
# ### True AI's Probs
# * Frontend, Connecting to APIs
# *
#
# ### q
# * How dev? status?
# * Research process?
#     * Take papers and experiment with new models?
#     * Did you go to NIPS -> guess you can just read the papers
#     *
# * What do you spend most of your time working on?
# * Where do your 'millions of historical convo logs' come from? Twitter
#     * Are they labelled 'good response or not'
#     * company historical data
#     * 1M+ questions
