# %% [markdown]
# Mon 10:14 Model has over 3 bn parameters. :O
# ```
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lambda_1 (Lambda)                (None, 160, 320, 3)   0           lambda_input_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 156, 316, 24)  1824        lambda_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 156, 316, 24)  0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 156, 316, 24)  0           activation_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 152, 312, 36)  21636       dropout_1[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 152, 312, 36)  0           convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 152, 312, 36)  0           activation_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 148, 308, 48)  43248       dropout_2[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 148, 308, 48)  0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 148, 308, 48)  0           activation_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 146, 306, 64)  27712       dropout_3[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 146, 306, 64)  0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 146, 306, 64)  0           activation_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 144, 304, 64)  36928       dropout_4[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 144, 304, 64)  0           convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 144, 304, 64)  0           activation_5[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 2801664)       0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1164)          3261138060  flatten_1[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 1164)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 1164)          0           activation_6[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 100)           116500      dropout_6[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 100)           0           dense_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 100)           0           activation_7[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 50)            5050        dropout_7[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 50)            0           dense_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 50)            0           activation_8[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 10)            510         dropout_8[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 10)            0           dense_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 10)            0           activation_9[0][0]
# ____________________________________________________________________________________________________
# dense_5 (Dense)                  (None, 1)             11          dropout_9[0][0]
# ====================================================================================================
# Total params: 3261391479
# ____________________________________________________________________________________________________
# ```

# %% [markdown]
# Down to 280M parameters after removing the first fc layer with 1164 neurons:
#
# ```
# __________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lambda_1 (Lambda)                (None, 160, 320, 3)   0           lambda_input_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 156, 316, 24)  1824        lambda_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 156, 316, 24)  0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 156, 316, 24)  0           activation_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 152, 312, 36)  21636       dropout_1[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 152, 312, 36)  0           convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 152, 312, 36)  0           activation_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 148, 308, 48)  43248       dropout_2[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 148, 308, 48)  0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 148, 308, 48)  0           activation_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 146, 306, 64)  27712       dropout_3[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 146, 306, 64)  0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 146, 306, 64)  0           activation_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 144, 304, 64)  36928       dropout_4[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 144, 304, 64)  0           convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 144, 304, 64)  0           activation_5[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 2801664)       0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 100)           280166500   flatten_1[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 100)           0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 100)           0           activation_6[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 50)            5050        dropout_6[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 50)            0           dense_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 50)            0           activation_7[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 10)            510         dropout_7[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 10)            0           dense_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 10)            0           activation_8[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 1)             11          dropout_8[0][0]
# ====================================================================================================
# Total params: 280303419
# ____________________________________________________________________________________________________
# ```

# %% [markdown]
# ```
# # NVIDIA End to End Learning Pipeline Model
#
# model = Sequential()
#
# # Crop the images
# # TODO: I think the cropping coords here are wrong. height should be 105.6
# # to preserve aspect ratio.
# model.add(Cropping2D(cropping=((22, 0), (0, 0)),
#                      input_shape=(160, 320, 3)))
#
# # Resize the data
# model.add(Lambda(resize))
#
# # Normalise data
# # TODO: some people use /255.0 - 0.5. Why?
# model.add(Lambda(lambda x: x/127.5 - 1.))
#
# # Conv layer 1, 5x5 kernel to 24@ (from 3@)
# # TODO: What does the number of filters MEAN?
# # Stride of 2x2
# model.add(Convolution2D(24, 5, 5,
#                         input_shape=(66,200))
#          )
#
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Conv layer 2, 5x5 kernel to 36@
# model.add(Convolution2D(36, 5, 5))
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Conv layer 3, 5x5 kernel to 48@
# model.add(Convolution2D(48, 5, 5))
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Conv layer 4, 3x3 kernel to 64@
# model.add(Convolution2D(64, 3, 3))
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Conv layer 5, 3x3 kernel to 64@
# model.add(Convolution2D(64, 3, 3))
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Flatten
# model.add(Flatten())
#
# # Removed: fully connected layer 1, 1164 neurons
#
# # Fc2, 100 neurons
# model.add(Dense(100))
# model.add(Activation('relu'))
# model.add(Dropout(0.1))
#
# # Fc3, 50 neurons
# model.add(Dense(50))
# model.add(Activation('relu'))
# model.add(Dropout(0.1))
#
# # Fc4, 10 neurons
# model.add(Dense(10))
# model.add(Activation('relu'))
# model.add(Dropout(0.1))
#
# # Output
# model.add(Dense(1))
#
# # Compile model
# # sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# adam = Adam(lr=0.0001)
# model.compile(loss='mean_squared_error',
#               optimizer=adam,
#               metrics=['accuracy'])
#
# model.summary()
# ```

# %% [markdown]
# ```
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# cropping2d_7 (Cropping2D)        (None, 138, 320, 3)   0           cropping2d_input_7[0][0]
# ____________________________________________________________________________________________________
# lambda_13 (Lambda)               (None, 66, 200, 3)    0           cropping2d_7[0][0]
# ____________________________________________________________________________________________________
# lambda_14 (Lambda)               (None, 66, 200, 3)    0           lambda_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_31 (Convolution2D) (None, 62, 196, 24)   1824        lambda_14[0][0]
# ____________________________________________________________________________________________________
# activation_49 (Activation)       (None, 62, 196, 24)   0           convolution2d_31[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_1 (SpatialDropo (None, 62, 196, 24)   0           activation_49[0][0]
# ____________________________________________________________________________________________________
# convolution2d_32 (Convolution2D) (None, 58, 192, 36)   21636       spatialdropout2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_50 (Activation)       (None, 58, 192, 36)   0           convolution2d_32[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_2 (SpatialDropo (None, 58, 192, 36)   0           activation_50[0][0]
# ____________________________________________________________________________________________________
# convolution2d_33 (Convolution2D) (None, 54, 188, 48)   43248       spatialdropout2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_51 (Activation)       (None, 54, 188, 48)   0           convolution2d_33[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_3 (SpatialDropo (None, 54, 188, 48)   0           activation_51[0][0]
# ____________________________________________________________________________________________________
# convolution2d_34 (Convolution2D) (None, 52, 186, 64)   27712       spatialdropout2d_3[0][0]
# ____________________________________________________________________________________________________
# activation_52 (Activation)       (None, 52, 186, 64)   0           convolution2d_34[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_4 (SpatialDropo (None, 52, 186, 64)   0           activation_52[0][0]
# ____________________________________________________________________________________________________
# convolution2d_35 (Convolution2D) (None, 50, 184, 64)   36928       spatialdropout2d_4[0][0]
# ____________________________________________________________________________________________________
# activation_53 (Activation)       (None, 50, 184, 64)   0           convolution2d_35[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_5 (SpatialDropo (None, 50, 184, 64)   0           activation_53[0][0]
# ____________________________________________________________________________________________________
# flatten_7 (Flatten)              (None, 588800)        0           spatialdropout2d_5[0][0]
# ____________________________________________________________________________________________________
# dense_25 (Dense)                 (None, 100)           58880100    flatten_7[0][0]
# ____________________________________________________________________________________________________
# activation_54 (Activation)       (None, 100)           0           dense_25[0][0]
# ____________________________________________________________________________________________________
# dropout_49 (Dropout)             (None, 100)           0           activation_54[0][0]
# ____________________________________________________________________________________________________
# dense_26 (Dense)                 (None, 50)            5050        dropout_49[0][0]
# ____________________________________________________________________________________________________
# activation_55 (Activation)       (None, 50)            0           dense_26[0][0]
# ____________________________________________________________________________________________________
# dropout_50 (Dropout)             (None, 50)            0           activation_55[0][0]
# ____________________________________________________________________________________________________
# dense_27 (Dense)                 (None, 10)            510         dropout_50[0][0]
# ____________________________________________________________________________________________________
# activation_56 (Activation)       (None, 10)            0           dense_27[0][0]
# ____________________________________________________________________________________________________
# dropout_51 (Dropout)             (None, 10)            0           activation_56[0][0]
# ____________________________________________________________________________________________________
# dense_28 (Dense)                 (None, 1)             11          dropout_51[0][0]
# ====================================================================================================
# Total params: 59017019
# ____________________________________________________________________________________________________
# ```

# %% [markdown]
# ### Reduced number of params to 1.8M
#
# Params in initial Dense layer have gone down significantly. Now the greatest contributors are the first few Conv layers.
# ```
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# cropping2d_19 (Cropping2D)       (None, 138, 320, 3)   0           cropping2d_input_19[0][0]
# ____________________________________________________________________________________________________
# lambda_37 (Lambda)               (None, 66, 200, 3)    0           cropping2d_19[0][0]
# ____________________________________________________________________________________________________
# lambda_38 (Lambda)               (None, 66, 200, 3)    0           lambda_37[0][0]
# ____________________________________________________________________________________________________
# convolution2d_89 (Convolution2D) (None, 31, 97, 24)    269592      lambda_38[0][0]
# ____________________________________________________________________________________________________
# activation_135 (Activation)      (None, 31, 97, 24)    0           convolution2d_89[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_57 (SpatialDrop (None, 31, 97, 24)    0           activation_135[0][0]
# ____________________________________________________________________________________________________
# convolution2d_90 (Convolution2D) (None, 14, 48, 36)    777636      spatialdropout2d_57[0][0]
# ____________________________________________________________________________________________________
# activation_136 (Activation)      (None, 14, 48, 36)    0           convolution2d_90[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_58 (SpatialDrop (None, 14, 48, 36)    0           activation_136[0][0]
# ____________________________________________________________________________________________________
# convolution2d_91 (Convolution2D) (None, 7, 17, 48)     442416      spatialdropout2d_58[0][0]
# ____________________________________________________________________________________________________
# activation_137 (Activation)      (None, 7, 17, 48)     0           convolution2d_91[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_59 (SpatialDrop (None, 7, 17, 48)     0           activation_137[0][0]
# ____________________________________________________________________________________________________
# convolution2d_92 (Convolution2D) (None, 5, 15, 64)     27712       spatialdropout2d_59[0][0]
# ____________________________________________________________________________________________________
# activation_138 (Activation)      (None, 5, 15, 64)     0           convolution2d_92[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_60 (SpatialDrop (None, 5, 15, 64)     0           activation_138[0][0]
# ____________________________________________________________________________________________________
# convolution2d_93 (Convolution2D) (None, 3, 13, 64)     36928       spatialdropout2d_60[0][0]
# ____________________________________________________________________________________________________
# activation_139 (Activation)      (None, 3, 13, 64)     0           convolution2d_93[0][0]
# ____________________________________________________________________________________________________
# spatialdropout2d_61 (SpatialDrop (None, 3, 13, 64)     0           activation_139[0][0]
# ____________________________________________________________________________________________________
# flatten_17 (Flatten)             (None, 2496)          0           spatialdropout2d_61[0][0]
# ____________________________________________________________________________________________________
# dense_65 (Dense)                 (None, 100)           249700      flatten_17[0][0]
# ____________________________________________________________________________________________________
# activation_140 (Activation)      (None, 100)           0           dense_65[0][0]
# ____________________________________________________________________________________________________
# dropout_79 (Dropout)             (None, 100)           0           activation_140[0][0]
# ____________________________________________________________________________________________________
# dense_66 (Dense)                 (None, 50)            5050        dropout_79[0][0]
# ____________________________________________________________________________________________________
# activation_141 (Activation)      (None, 50)            0           dense_66[0][0]
# ____________________________________________________________________________________________________
# dropout_80 (Dropout)             (None, 50)            0           activation_141[0][0]
# ____________________________________________________________________________________________________
# dense_67 (Dense)                 (None, 10)            510         dropout_80[0][0]
# ____________________________________________________________________________________________________
# activation_142 (Activation)      (None, 10)            0           dense_67[0][0]
# ____________________________________________________________________________________________________
# dropout_81 (Dropout)             (None, 10)            0           activation_142[0][0]
# ____________________________________________________________________________________________________
# dense_68 (Dense)                 (None, 1)             11          dropout_81[0][0]
# ====================================================================================================
# Total params: 1809555
# ```
#
# Model used:
# ```
# # NVIDIA End to End Learning Pipeline Model
#
# model = Sequential()
#
# # Crop the images
# # TODO: I think the cropping coords here are wrong. height should be 105.6
# # to preserve aspect ratio.
# model.add(Cropping2D(cropping=((22, 0), (0, 0)),
#                      input_shape=(160, 320, 3)))
#
# # Resize the data
# model.add(Lambda(resize))
#
# # Normalise data
# # TODO: some people use /255.0 - 0.5. Why?
# model.add(Lambda(lambda x: x/127.5 - 1.))
#
# # Conv layer 1, 5x5 kernel to 24@ (from 3@)
# # TODO: What does the number of filters MEAN?
# # Stride of 2x2
# model.add(Convolution2D(24, 36, 104,
#                         input_shape=(66,200))
#          )
#
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Conv layer 2, 5x5 kernel to 36@
# model.add(Convolution2D(36, 18, 50))
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Conv layer 3, 5x5 kernel to 48@
# model.add(Convolution2D(48, 8, 32))
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Conv layer 4, 3x3 kernel to 64@
# model.add(Convolution2D(64, 3, 3))
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Conv layer 5, 3x3 kernel to 64@
# model.add(Convolution2D(64, 3, 3))
# model.add(Activation('relu'))
# model.add(SpatialDropout2D(0.1))
#
# # Flatten
# model.add(Flatten())
#
# # Removed: fully connected layer 1, 1164 neurons
#
# # Fc2, 100 neurons
# model.add(Dense(100))
# model.add(Activation('relu'))
# model.add(Dropout(0.1))
#
# # Fc3, 50 neurons
# model.add(Dense(50))
# model.add(Activation('relu'))
# model.add(Dropout(0.1))
#
# # Fc4, 10 neurons
# model.add(Dense(10))
# model.add(Activation('relu'))
# model.add(Dropout(0.1))
#
# # Output
# model.add(Dense(1))
#
# # Compile model
# # sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# adam = Adam(lr=0.0001)
# model.compile(loss='mean_squared_error',
#               optimizer=adam,
#               metrics=['accuracy'])
#
# model.summary()
# ```
# ____________________________________________________________________________________________________

# %% [markdown]
# # Tues 14 Feb 17:00

# %% [markdown]
# New comma model with new resize layer (not Nvidia's size) and cut an extra 10pixels off the top of the image. Call this Comma V2. No dropout.
#
# ```
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# cropping2d_80 (Cropping2D)       (None, 90, 320, 3)    0           cropping2d_input_80[0][0]
# ____________________________________________________________________________________________________
# lambda_189 (Lambda)              (None, 40, 160, 3)    0           cropping2d_80[0][0]
# ____________________________________________________________________________________________________
# lambda_190 (Lambda)              (None, 40, 160, 1)    0           lambda_189[0][0]
# ____________________________________________________________________________________________________
# lambda_191 (Lambda)              (None, 40, 160, 1)    0           lambda_190[0][0]
# ____________________________________________________________________________________________________
# convolution2d_264 (Convolution2D (None, 10, 40, 16)    1040        lambda_191[0][0]
# ____________________________________________________________________________________________________
# elu_63 (ELU)                     (None, 10, 40, 16)    0           convolution2d_264[0][0]
# ____________________________________________________________________________________________________
# convolution2d_265 (Convolution2D (None, 5, 20, 32)     12832       elu_63[0][0]
# ____________________________________________________________________________________________________
# elu_64 (ELU)                     (None, 5, 20, 32)     0           convolution2d_265[0][0]
# ____________________________________________________________________________________________________
# convolution2d_266 (Convolution2D (None, 3, 10, 64)     51264       elu_64[0][0]
# ____________________________________________________________________________________________________
# flatten_53 (Flatten)             (None, 1920)          0           convolution2d_266[0][0]
# ____________________________________________________________________________________________________
# elu_65 (ELU)                     (None, 1920)          0           flatten_53[0][0]
# ____________________________________________________________________________________________________
# dense_175 (Dense)                (None, 512)           983552      elu_65[0][0]
# ____________________________________________________________________________________________________
# elu_66 (ELU)                     (None, 512)           0           dense_175[0][0]
# ____________________________________________________________________________________________________
# dense_176 (Dense)                (None, 1)             513         elu_66[0][0]
# ====================================================================================================
# Total params: 1049201
# ____________________________________________________________________________________________________
# ```

# %% [markdown]
# v2 performance:
#
# 2: doesn't make it past first curve, swerves left
# 5: swerves left after the rock and drives into water
# 10 (and 11): goes right just before the bridge into a pool
# 12: crashes into right of bridge
# 15: drives into water again

# %% [markdown]
# v2 with augmented data (40 datapoints) performance:
#
# It keeps going to the right. I need to change the steering angles on the augmented files CSV, reduce their magnitude so it goes left but not too left. (Many are at -1.0 and so are skewing the weights.)

# %% [markdown]
# v2 with augmented data 2 (18 datapoints) performance:
#
# (I reduced the magnitude of steering angles and cut the augmented data to 18 datapoints.)
#
# Dreadful. 10 epochs it went into the water before the bridge (right turn), more epochs it went right after the rock into the water.

# %% [markdown]
# v2c with augmented data (further reduced angle) performance
#
# still poor

# %% [markdown]
# v2d: normalise change to /255.0 - 0.5, don't use augmented data any more.

# %% [markdown]
# v2e: use augmented data (flipped images with flipped angles)
#
# the angles are tiny. It basically drives straight.
#
# :(

# %% [markdown]
# v2f: use the original data, normalise /255.0 - 0.5.
#
# crop 70, 25 instead.

# %% [markdown]
# v3a: use udacity, extra laps and recovery data
# * shit
#
# v3b: use udacity and recovery data
#
# v3c: use udacity and extra laps data
#
# v3d: use udacity and mouse data
#
# v3e: use udacity and mouse data, 3 channel comma AI
#
# v3f: use udacity data only, 3 channel comma AI
#
# v3g: use udacity data + Annie's recovery data, 3 channel comma
# * 10: Turns left into the water before the big turn (red and white outlined)
# * 12: crashes into the left arm of the bridge and still wants to go left after
# * 14: Turns left (onto the edge of the track, so a persistent slight left turn) before the rock
#
# * 8: We've made it. We've made it to the Promised Land!!! :O

# %% [markdown]
# NVIDIA
#
# v1a: Using Udacity data only
# * Swerves to the left soon after starting
#
# v1b: using Udacity's data + annie's recovery data
# * Also swerves to the left soon after starting

# %% [markdown]
# Friday: the model no longer drives well. I've tried epoch 7-9, none work. Well this is fun, isn't it?
#
# Next time take a video while the model is working.
#
# v4a: use udacity data + Annie's recovery data, 3 channel comma **with dropout**.
#
# v4b: I'm just going to retrain 3g. Serious.
# - WITH an extra Dense(50) layer with ELU activation. K.
#
# 4b.19 can do
