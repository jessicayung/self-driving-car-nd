# %% [markdown]
# # **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note** If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
# Read and save test images to array

import os
os.listdir("test_images/")

def read_image(image_path):
    return mpimg.imread(image_path)

test_images = [read_image('test_images/' + i) for i in os.listdir('test_images/')]

# %%
def read_image_and_print_dims(image_path):
    #reading in an image
    image = mpimg.imread(image_path)
    #printing out some stats and plotting
    print('This image is:', type(image), 'with dimensions:', image.shape)
    plt.imshow(image)  #call as plt.imshow(gray, cmap='gray') to show a grayscaled image
    return image

# %%
read_image_and_print_dims('test_images/solidWhiteRight.jpg')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)
# array([[[180, 196, 209],
#         [142, 161, 176],
#         [134, 156, 179],
#         ...,
#         [136, 154, 178],
#         [146, 159, 176],
#         [186, 195, 210]],
#
#        [[142, 161, 176],
#         [143, 166, 184],
#         [134, 160, 183],
#         ...,
#         [137, 159, 183],
#         [142, 159, 179],
#         [148, 161, 178]],
#
#        [[131, 158, 179],
#         [133, 161, 183],
#         [128, 159, 187],
#         ...,
#         [129, 156, 185],
#         [136, 158, 182],
#         [134, 152, 176]],
#
#        ...,
#        [[120, 121, 125],
#         [ 91,  92,  97],
#         [ 83,  84,  89],
#         ...,
#         [ 88,  89,  93],
#         [ 94,  95,  99],
#         [120, 121, 125]],
#
#        [[138, 139, 143],
#         [105, 106, 110],
#         [ 89,  90,  95],
#         ...,
#         [ 97,  98, 102],
#         [109, 110, 114],
#         [139, 140, 144]],
#
#        [[180, 181, 185],
#         [140, 141, 145],
#         [117, 118, 123],
#         ...,
#         [122, 123, 125],
#         [140, 141, 143],
#         [179, 180, 182]]], dtype=uint8)

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), 
                            minLineLength=min_line_len, maxLineGap=max_line_gap)
    # print("Hough lines: ", lines)
    line_img = np.zeros(img.shape, dtype=np.uint8)
    draw_lines(line_img, lines)
    return line_img

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %%
def find_linear_regression_line(points):
    # Separate points into X and y to fit LinearRegression model
    points_x = [[point[0]] for point in points]
    points_y = [point[1] for point in points]
    # points_x_print = [point[0] for point in points]
    # print("X points: ", points_x, "Length: ", len(points_x))
    # print("X points: ", points_x_print, "Length: ", len(points_x))
    # print("Y points: ", points_y, "Length: ", len(points_y))

    # Fit points to LinearRegression line
    clf = LinearRegression().fit(points_x, points_y)

    # Get parameters from line
    coef = clf.coef_[0]
    intercept = clf.intercept_
    print("Coefficients: ", coef, "Intercept: ", intercept)
    return coef, intercept

def intersection_x(coef1, intercept1, coef2, intercept2):
    """Returns x-coordinate of intersection of two lines."""
    x = (intercept2-intercept1)/(coef1-coef2)
    return x

def draw_linear_regression_line(coef, intercept, intersection_x, img, imshape=[540,960], color=[255, 0, 0], thickness=2):
    
    # Get starting and ending points of regression line, ints.
    point_one = (int(intersection_x), int(intersection_x * coef + intercept))
    if coef > 0:
        point_two = (imshape[1], int(imshape[1] * coef + intercept))
    elif coef < 0:
        point_two = (0, int(0 * coef + intercept))
    print("Point one: ", point_one, "Point two: ", point_two)
    
    
    # Draw line using cv2.line
    cv2.line(img, point_one, point_two, color, thickness)

# %%
def draw_lines(img, lines, color=[255, 0, 0], thickness=2):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    # Image parameters (hard-coded. TODO: Make not hard-coded.)
    imshape = [540, 960]
    
    # Initialise arrays
    positive_slope_points = []
    negative_slope_points = []
    positive_slope_intercept = []
    negative_slope_intercept = []
    
    for line in lines:
        for x1,y1,x2,y2 in line:            
            slope = (y2-y1)/(x2-x1)
            # middle_point = [(x1+x2)/2, (y1+y2)/2]
            # print("Points: ", [x1, y1, x2, y2])
            length = math.sqrt((x1-x2)**2 + (y1-y2)**2)
            # print("Length: ", length)
            if length > 50:
                if slope > 0:
                    # positive_slope_points.append(middle_point)
                    positive_slope_points.append([x1, y1])
                    positive_slope_points.append([x2, y2])
                    positive_slope_intercept.append([slope, y1-slope*x1])
                elif slope < 0:
                    # negative_slope_points.append(middle_point)
                    negative_slope_points.append([x1, y1])
                    negative_slope_points.append([x2, y2])
    positive_slope_points = np.array(positive_slope_points)
    negative_slope_points = np.array(negative_slope_points)
    # print("positive slope line points: ", positive_slope_points)
    # print("negative slope line points: ", negative_slope_points)
    # print("positive slope points dtype: ", positive_slope_points.dtype)

    # Remove 5% percentile on each side
    # positive_slope_intercept = sorted(positive_slope_intercept)
    positive_slopes = [pair[0] for pair in positive_slope_intercept]
    positive_intercepts = [pair[1] for pair in positive_slope_intercept]
    mean_slope = np.mean(positive_slopes)
    slope_std = np.std(positive_slopes)
    for pair in positive_slope_intercept:
        slope = pair[0]
        if slope - mean_slope < 1.5*slope_std:
            kept_positive_slopes.append(slope)
            kept_positive_intercepts.append(pair[1])
    
    # Take estimate to be the mean of remaining values
    positive_slope = np.mean(kept_positive_slopes)
    positive_intercept = np.mean(kept_positive_intercepts)
    print("Positive slope: ", positive_slope, "Positive intercept: ", positive_intercept)
    # Get intercept and coefficient regression lines
    pos_coef, pos_intercept = find_linear_regression_line(positive_slope_points)
    neg_coef, neg_intercept = find_linear_regression_line(negative_slope_points)
    
    # Get intersection point
    intersection_x_coord = intersection_x(pos_coef, pos_intercept, neg_coef, neg_intercept)
    
    # Plot lines
    draw_linear_regression_line(pos_coef, pos_intercept, intersection_x_coord, img)
    draw_linear_regression_line(neg_coef, neg_intercept, intersection_x_coord, img)

# %%
a = [1,3,5,6,6]
b = [[1,2], [3,4],[1,10]]
np.percentile(b,95)
np.std(a)
# Out:
# 1.9390719429665317

# %%
help(np.std)
# Out:
# Help on function std in module numpy.core.fromnumeric:
#
# std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=False)
#     Compute the standard deviation along the specified axis.
#
#     Returns the standard deviation, a measure of the spread of a distribution,
#     of the array elements. The standard deviation is computed for the
#     flattened array by default, otherwise over the specified axis.
#
#     Parameters
#     ----------
#     a : array_like
#         Calculate the standard deviation of these values.
#     axis : None or int or tuple of ints, optional
#         Axis or axes along which the standard deviation is computed. The
#         default is to compute the standard deviation of the flattened array.
#
#         .. versionadded: 1.7.0
#
#         If this is a tuple of ints, a standard deviation is performed over
#         multiple axes, instead of a single axis or all the axes as before.
#     dtype : dtype, optional
#         Type to use in computing the standard deviation. For arrays of
#         integer type the default is float64, for arrays of float types it is
#         the same as the array type.
#     out : ndarray, optional
#         Alternative output array in which to place the result. It must have
#         the same shape as the expected output but the type (of the calculated
#         values) will be cast if necessary.
#     ddof : int, optional
#         Means Delta Degrees of Freedom.  The divisor used in calculations
#         is ``N - ddof``, where ``N`` represents the number of elements.
#         By default `ddof` is zero.
#     keepdims : bool, optional
#         If this is set to True, the axes which are reduced are left
#         in the result as dimensions with size one. With this option,
#         the result will broadcast correctly against the original `arr`.
#
#     Returns
#     -------
#     standard_deviation : ndarray, see dtype parameter above.
#         If `out` is None, return a new array containing the standard deviation,
#         otherwise return a reference to the output array.
#
#     See Also
#     --------
#     var, mean, nanmean, nanstd, nanvar
#     numpy.doc.ufuncs : Section "Output arguments"
#
#     Notes
#     -----
#     The standard deviation is the square root of the average of the squared
#     deviations from the mean, i.e., ``std = sqrt(mean(abs(x - x.mean())**2))``.
#
#     The average squared deviation is normally calculated as
#     ``x.sum() / N``, where ``N = len(x)``.  If, however, `ddof` is specified,
#     the divisor ``N - ddof`` is used instead. In standard statistical
#     practice, ``ddof=1`` provides an unbiased estimator of the variance
#     of the infinite population. ``ddof=0`` provides a maximum likelihood
#     estimate of the variance for normally distributed variables. The
#     standard deviation computed in this function is the square root of
#     the estimated variance, so even with ``ddof=1``, it will not be an
#     unbiased estimate of the standard deviation per se.
#
#     Note that, for complex numbers, `std` takes the absolute
#     value before squaring, so that the result is always real and nonnegative.
#
#     For floating-point input, the *std* is computed using the same
#     precision the input has. Depending on the input data, this can cause
#     the results to be inaccurate, especially for float32 (see example below).
#     Specifying a higher-accuracy accumulator using the `dtype` keyword can
#     alleviate this issue.
#
#     Examples
#     --------
#     >>> a = np.array([[1, 2], [3, 4]])
#     >>> np.std(a)
#     1.1180339887498949
#     >>> np.std(a, axis=0)
#     array([ 1.,  1.])
#     >>> np.std(a, axis=1)
#     array([ 0.5,  0.5])
#
#     In single precision, std() can be inaccurate:
#
#     >>> a = np.zeros((2, 512*512), dtype=np.float32)
#     >>> a[0, :] = 1.0
#     >>> a[1, :] = 0.1
#     >>> np.std(a)
#     0.45000005
#
#     Computing the standard deviation in float64 is more accurate:
#
#     >>> np.std(a, dtype=np.float64)
#     0.44999999925494177

# %%
# Pipeline

def draw_lane_lines(image):
    """Draw lane lines in white on original image."""
    # Print image details
    # print("image.shape: ", image.shape)
    imshape = image.shape
    
    # Greyscale image
    greyscaled_image = grayscale(image)
    # plt.imshow(greyscaled_image, cmap="gray")
    # print("Greyscaled image dims: ", greyscaled_image.shape)
    
    # Gaussian Blur
    blurred_grey_image = gaussian_blur(greyscaled_image, 5)
    
    # Canny edge detection
    edges_image = canny(blurred_grey_image, 50, 150)
    # (80,540),(460, 280), (490, 280), (900,540)
    
    # Mask image
    border = 0
    vertices = np.array([[(0,imshape[0]),(465, 320), (475, 320), (imshape[1],imshape[0])]], dtype=np.int32)
    edges_image_with_mask = region_of_interest(edges_image, vertices)
    # plt.subplot(2,1,1)
    bw_edges_image_with_mask = cv2.cvtColor(edges_image_with_mask, cv2.COLOR_GRAY2BGR)
    plt.imshow(bw_edges_image_with_mask)
    
    # Hough lines
    rho = 2 # distance resolution in pixels of the Hough grid
    theta = np.pi/180 # angular resolution in radians of the Hough grid
    threshold = 15     # minimum number of votes (intersections in Hough grid cell)
    min_line_len = 20 #minimum number of pixels making up a line
    max_line_gap = 40    # maximum gap in pixels between connectable line segments
    lines_image = hough_lines(edges_image_with_mask, rho, theta, threshold, min_line_len, max_line_gap)
    # print("Hough output image.shape: ", lines_image.shape)
    # plt.imshow(lines_image)
    # print("lines_image: ", lines_image)
    
    # Convert Hough from single channel to RGB to prep for weighted
    # TODO: Have it convert the lines to red, not white.
    hough_rgb_image = cv2.cvtColor(lines_image, cv2.COLOR_GRAY2BGR)
    print("hough_rgb.shape: ", hough_rgb_image.shape)
    # plt.imshow(hough_rgb_image)
    
    print("hough_rgb.type: ", hough_rgb_image.dtype)
    # print(hough_rgb_image)
    
    # Combine lines image with original image
    final_image = weighted_img(hough_rgb_image, image)
    # plt.subplot(2,1,2)
    plt.imshow(final_image)
    return final_image
    # plt.show()

draw_lane_lines(test_images[0])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-144-a1a6c90213f8> in <module>()
#      54     # plt.show()
#      55
# ---> 56 draw_lane_lines(test_images[0])
#
# <ipython-input-144-a1a6c90213f8> in draw_lane_lines(image)
#      33     min_line_len = 20 #minimum number of pixels making up a line
#      34     max_line_gap = 40    # maximum gap in pixels between connectable line segments
# ---> 35     lines_image = hough_lines(edges_image_with_mask, rho, theta, threshold, min_line_len, max_line_gap)
#      36     # print("Hough output image.shape: ", lines_image.shape)
#      37     # plt.imshow(lines_image)
#
# <ipython-input-41-1277c96849a8> in hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap)
#      50     # print("Hough lines: ", lines)
#      51     line_img = np.zeros(img.shape, dtype=np.uint8)
# ---> 52     draw_lines(line_img, lines)
#      53     return line_img
#      54
#
# <ipython-input-143-46aa8266d8e8> in draw_lines(img, lines, color, thickness)
#      50     # Remove 5% percentile on each side
#      51     positive_slope_intercept = sorted(positive_slope_intercept)
# ---> 52     mean_slope = np.mean(positive_slopes)
#      53     slope_std = np.std(positive_slopes)
#      54     for pair in positive_slope_intercept:
#
# UnboundLocalError: local variable 'positive_slopes' referenced before assignment

# %%
for image in test_images:
    draw_lane_lines(image)
# Out:
# Points:  [583, 369, 877, 538]
# Length:  339.11207586873104
# Points:  [626, 388, 898, 538]
# Length:  310.61873736141547
# Points:  [292, 462, 461, 325]
# Length:  217.55459085020476
# Points:  [280, 460, 460, 324]
# Length:  225.6014184352572
# Points:  [651, 401, 897, 537]
# Length:  281.0907326825273
# Points:  [588, 371, 872, 535]
# Length:  327.95121588431414
# Points:  [307, 439, 462, 322]
# Length:  194.20092687729377
# Points:  [351, 410, 468, 322]
# Length:  146.40013661195812
# Points:  [318, 440, 342, 421]
# Points:  [281, 460, 305, 442]
# Points:  [441, 343, 469, 322]
# positive slope line points:  [[ 730.   453.5]
#  [ 762.   463. ]
#  [ 774.   469. ]
#  [ 730.   453. ]]
# negative slope line points:  [[ 376.5  393.5]
#  [ 370.   392. ]
#  [ 384.5  380.5]
#  [ 409.5  366. ]]
# positive slope points dtype:  float64
# dtype printed
# X points:  [[730.0], [762.0], [774.0], [730.0]] Length:  4
# X points:  [730.0, 762.0, 774.0, 730.0] Length:  4
# Y points:  [453.5, 463.0, 469.0, 453.0] Length:  4
# Coefficients:  0.343337730871 Intercept:  202.465039578
# X points:  [[376.5], [370.0], [384.5], [409.5]] Length:  4
# X points:  [376.5, 370.0, 384.5, 409.5] Length:  4
# Y points:  [393.5, 392.0, 380.5, 366.0] Length:  4
# Coefficients:  -0.712385991784 Intercept:  657.357655086
# Point one:  (430, 350) Point two:  (960, 532)
# Point one:  (430, 350) Point two:  (0, 657)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# Points:  [550, 354, 822, 531]
# Length:  324.5196450139806
# Points:  [573, 364, 853, 539]
# Length:  330.1893396219811
# Points:  [319, 425, 464, 320]
# Length:  179.02513789968157
# Points:  [310, 423, 460, 322]
# Length:  180.83417818543043
# Points:  [553, 355, 582, 373]
# Points:  [800, 518, 832, 538]
# Points:  [362, 392, 453, 326]
# Length:  112.4144118874444
# Points:  [406, 357, 445, 329]
# Points:  [165, 521, 187, 521]
# Points:  [712, 460, 754, 487]
# Points:  [551, 354, 719, 463]
# Length:  200.26232796010336
# Points:  [777, 503, 797, 515]
# Points:  [581, 368, 625, 395]
# Length:  51.62363799656123
# Points:  [316, 425, 394, 372]
# Length:  94.30270409696638
# Points:  [799, 517, 820, 517]
# Points:  [796, 515, 817, 515]
# Points:  [361, 392, 418, 354]
# Length:  68.5054742338158
# Points:  [739, 478, 771, 498]
# Points:  [809, 510, 853, 538]
# Length:  52.15361924162119
# positive slope line points:  [[ 686.   442.5]
#  [ 713.   451.5]
#  [ 635.   408.5]
#  [ 603.   381.5]
#  [ 831.   524. ]]
# negative slope line points:  [[ 391.5  372.5]
#  [ 385.   372.5]
#  [ 407.5  359. ]
#  [ 355.   398.5]
#  [ 389.5  373. ]]
# positive slope points dtype:  float64
# dtype printed
# X points:  [[686.0], [713.0], [635.0], [603.0], [831.0]] Length:  5
# X points:  [686.0, 713.0, 635.0, 603.0, 831.0] Length:  5
# Y points:  [442.5, 451.5, 408.5, 381.5, 524.0] Length:  5
# Coefficients:  0.610291647284 Intercept:  18.3017134439
# X points:  [[391.5], [385.0], [407.5], [355.0], [389.5]] Length:  5
# X points:  [391.5, 385.0, 407.5, 355.0, 389.5] Length:  5
# Y points:  [372.5, 372.5, 359.0, 398.5, 373.0] Length:  5
# Coefficients:  -0.743776853304 Intercept:  661.974732319
# Point one:  (475, 308) Point two:  (960, 604)
# Point one:  (475, 308) Point two:  (0, 661)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# Points:  [154, 538, 456, 326]
# Length:  368.982384403375
# Points:  [308, 440, 438, 342]
# Length:  162.80049139974977
# Points:  [192, 526, 266, 469]
# Length:  93.40770846134703
# Points:  [576, 374, 651, 419]
# Length:  87.46427842267951
# Points:  [548, 356, 658, 417]
# Length:  125.78155667664477
# Points:  [155, 538, 450, 331]
# Length:  360.3803546254984
# Points:  [269, 467, 294, 450]
# Points:  [605, 393, 649, 419]
# Length:  51.10772935672255
# Points:  [526, 343, 658, 416]
# Length:  150.8409758653132
# Points:  [184, 532, 211, 510]
# Points:  [767, 492, 793, 493]
# Points:  [433, 340, 457, 324]
# Points:  [551, 354, 583, 374]
# Points:  [305, 442, 374, 385]
# Length:  89.49860334105779
# Points:  [771, 494, 792, 491]
# Points:  [251, 482, 441, 339]
# Length:  237.80033641691932
# Points:  [174, 538, 260, 475]
# Length:  106.60675400742676
# Points:  [424, 347, 455, 326]
# positive slope line points:  [[ 613.5  396.5]
#  [ 603.   386.5]
#  [ 627.   406. ]
#  [ 592.   379.5]]
# negative slope line points:  [[ 305.   432. ]
#  [ 373.   391. ]
#  [ 229.   497.5]
#  [ 302.5  434.5]
#  [ 339.5  413.5]
#  [ 346.   410.5]
#  [ 217.   506.5]]
# positive slope points dtype:  float64
# dtype printed
# X points:  [[613.5], [603.0], [627.0], [592.0]] Length:  4
# X points:  [613.5, 603.0, 627.0, 592.0] Length:  4
# Y points:  [396.5, 386.5, 406.0, 379.5] Length:  4
# Coefficients:  0.773792845802 Intercept:  -79.0181189876
# X points:  [[305.0], [373.0], [229.0], [302.5], [339.5], [346.0], [217.0]] Length:  7
# X points:  [305.0, 373.0, 229.0, 302.5, 339.5, 346.0, 217.0] Length:  7
# Y points:  [432.0, 391.0, 497.5, 434.5, 413.5, 410.5, 506.5] Length:  7
# Coefficients:  -0.746967532047 Intercept:  666.156489669
# Point one:  (490, 300) Point two:  (960, 663)
# Point one:  (490, 300) Point two:  (0, 666)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# Points:  [160, 539, 456, 324]
# Length:  365.8428624423333
# Points:  [238, 492, 460, 324]
# Length:  278.40258619488435
# Points:  [710, 445, 874, 539]
# Length:  189.02909828912584
# Points:  [700, 446, 739, 471]
# Points:  [700, 445, 844, 535]
# Length:  169.81166037701888
# Points:  [179, 538, 332, 422]
# Length:  192.00260414900626
# Points:  [159, 538, 372, 384]
# Length:  262.8402556687236
# Points:  [716, 447, 875, 538]
# Length:  183.19934497699495
# Points:  [408, 360, 455, 325]
# Length:  58.60034129593445
# Points:  [809, 512, 851, 539]
# Points:  [579, 367, 627, 396]
# Length:  56.08029957123981
# Points:  [415, 360, 460, 325]
# Length:  57.0087712549569
# Points:  [553, 355, 584, 375]
# Points:  [181, 537, 211, 515]
# Points:  [577, 370, 629, 400]
# Length:  60.03332407921454
# Points:  [409, 364, 460, 323]
# Length:  65.43699259593154
# Points:  [274, 465, 298, 464]
# Points:  [214, 467, 299, 461]
# Length:  85.21150157109074
# Points:  [219, 462, 266, 460]
# Points:  [570, 363, 631, 400]
# Length:  71.34423592694787
# Points:  [702, 448, 781, 497]
# Length:  92.9623579735368
# positive slope line points:  [[ 792.   492. ]
#  [ 772.   490. ]
#  [ 795.5  492.5]
#  [ 603.   381.5]
#  [ 603.   385. ]
#  [ 600.5  381.5]
#  [ 741.5  472.5]]
# negative slope line points:  [[ 308.   431.5]
#  [ 349.   408. ]
#  [ 255.5  480. ]
#  [ 265.5  461. ]
#  [ 431.5  342.5]
#  [ 437.5  342.5]
#  [ 434.5  343.5]
#  [ 256.5  464. ]]
# positive slope points dtype:  float64
# dtype printed
# X points:  [[792.0], [772.0], [795.5], [603.0], [603.0], [600.5], [741.5]] Length:  7
# X points:  [792.0, 772.0, 795.5, 603.0, 603.0, 600.5, 741.5] Length:  7
# Y points:  [492.0, 490.0, 492.5, 381.5, 385.0, 381.5, 472.5] Length:  7
# Coefficients:  0.593237872746 Intercept:  26.2407342141
# X points:  [[308.0], [349.0], [255.5], [265.5], [431.5], [437.5], [434.5], [256.5]] Length:  8
# X points:  [308.0, 349.0, 255.5, 265.5, 431.5, 437.5, 434.5, 256.5] Length:  8
# Y points:  [431.5, 408.0, 480.0, 461.0, 342.5, 342.5, 343.5, 464.0] Length:  8
# Coefficients:  -0.714311258835 Intercept:  653.598028336
# Point one:  (479, 310) Point two:  (960, 595)
# Point one:  (479, 310) Point two:  (0, 653)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# Points:  [172, 529, 450, 327]
# Length:  343.63934582640564
# Points:  [177, 513, 271, 448]
# Length:  114.28473213863697
# Points:  [310, 423, 397, 362]
# Length:  106.25441167311595
# Points:  [661, 424, 768, 493]
# Length:  127.3184982632139
# Points:  [671, 424, 783, 491]
# Length:  130.51053597315428
# Points:  [138, 539, 169, 517]
# Points:  [260, 457, 290, 435]
# Points:  [158, 539, 330, 414]
# Length:  212.6240814207083
# Points:  [285, 440, 341, 400]
# Length:  68.81860213634101
# Points:  [410, 351, 432, 336]
# Points:  [391, 365, 440, 334]
# Length:  57.982756057296896
# Points:  [181, 510, 203, 494]
# Points:  [558, 358, 605, 387]
# Length:  55.226805085936306
# Points:  [171, 517, 191, 502]
# Points:  [347, 396, 448, 328]
# Length:  121.75795661885921
# Points:  [673, 424, 784, 491]
# Length:  129.65338406690356
# Points:  [662, 424, 769, 493]
# Length:  127.3184982632139
# Points:  [216, 487, 257, 458]
# Length:  50.21951811795888
# Points:  [577, 368, 601, 384]
# Points:  [674, 433, 715, 460]
# Points:  [330, 420, 429, 337]
# Length:  129.18978287774928
# Points:  [741, 467, 780, 490]
# Points:  [328, 419, 404, 360]
# Length:  96.21330469326995
# Points:  [578, 368, 603, 384]
# Points:  [288, 437, 338, 419]
# Length:  53.14132102234569
# positive slope line points:  [[ 714.5  458.5]
#  [ 727.   457.5]
#  [ 581.5  372.5]
#  [ 728.5  457.5]
#  [ 715.5  458.5]]
# negative slope line points:  [[ 311.   428. ]
#  [ 224.   480.5]
#  [ 353.5  392.5]
#  [ 244.   476.5]
#  [ 313.   420. ]
#  [ 415.5  349.5]
#  [ 397.5  362. ]
#  [ 236.5  472.5]
#  [ 379.5  378.5]
#  [ 366.   389.5]
#  [ 313.   428. ]]
# positive slope points dtype:  float64
# dtype printed
# X points:  [[714.5], [727.0], [581.5], [728.5], [715.5]] Length:  5
# X points:  [714.5, 727.0, 581.5, 728.5, 715.5] Length:  5
# Y points:  [458.5, 457.5, 372.5, 457.5, 458.5] Length:  5
# Coefficients:  0.604108445771 Intercept:  22.0112037025
# X points:  [[311.0], [224.0], [353.5], [244.0], [313.0], [415.5], [397.5], [236.5], [379.5], [366.0], [313.0]] Length:  11
# X points:  [311.0, 224.0, 353.5, 244.0, 313.0, 415.5, 397.5, 236.5, 379.5, 366.0, 313.0] Length:  11
# Y points:  [428.0, 480.5, 392.5, 476.5, 420.0, 349.5, 362.0, 472.5, 378.5, 389.5, 428.0] Length:  11
# Coefficients:  -0.694156701837 Intercept:  640.380530907
# Point one:  (476, 309) Point two:  (960, 601)
# Point one:  (476, 309) Point two:  (0, 640)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# Points:  [253, 480, 473, 320]
# Length:  272.02941017470886
# Points:  [195, 538, 470, 323]
# Length:  349.07019351414124
# Points:  [743, 467, 863, 539]
# Length:  139.9428454762872
# Points:  [752, 465, 884, 538]
# Length:  150.8409758653132
# Points:  [225, 501, 258, 478]
# Points:  [754, 465, 816, 499]
# Length:  70.71067811865476
# Points:  [564, 360, 651, 410]
# Length:  100.34440691936945
# Points:  [176, 539, 202, 518]
# Points:  [242, 490, 284, 487]
# Points:  [353, 413, 380, 393]
# Points:  [352, 406, 390, 385]
# Points:  [434, 353, 462, 324]
# Points:  [743, 466, 863, 538]
# Length:  139.9428454762872
# Points:  [207, 516, 227, 500]
# Points:  [357, 402, 395, 381]
# Points:  [582, 369, 606, 382]
# Points:  [343, 413, 373, 398]
# Points:  [203, 533, 286, 468]
# Length:  105.4229576515476
# Points:  [354, 405, 388, 387]
# Points:  [210, 512, 311, 438]
# Length:  125.2078272313676
# Points:  [438, 350, 465, 322]
# Points:  [395, 375, 432, 354]
# Points:  [823, 505, 869, 530]
# Length:  52.354560450833695
# Points:  [367, 395, 403, 375]
# Points:  [209, 513, 231, 498]
# Points:  [414, 361, 471, 322]
# Length:  69.06518659932803
# Points:  [348, 409, 384, 390]
# Points:  [276, 474, 306, 451]
# Points:  [339, 416, 367, 402]
# Points:  [391, 378, 430, 356]
# positive slope line points:  [[ 803.   503. ]
#  [ 818.   501.5]
#  [ 785.   482. ]
#  [ 607.5  385. ]
#  [ 803.   502. ]
#  [ 846.   517.5]]
# negative slope line points:  [[ 363.   400. ]
#  [ 332.5  430.5]
#  [ 244.5  500.5]
#  [ 260.5  475. ]
#  [ 442.5  341.5]]
# positive slope points dtype:  float64
# dtype printed
# X points:  [[803.0], [818.0], [785.0], [607.5], [803.0], [846.0]] Length:  6
# X points:  [803.0, 818.0, 785.0, 607.5, 803.0, 846.0] Length:  6
# Y points:  [503.0, 501.5, 482.0, 385.0, 502.0, 517.5] Length:  6
# Coefficients:  0.567302534856 Intercept:  40.9919885391
# X points:  [[363.0], [332.5], [244.5], [260.5], [442.5]] Length:  5
# X points:  [363.0, 332.5, 244.5, 260.5, 442.5] Length:  5
# Y points:  [400.0, 430.5, 500.5, 475.0, 341.5] Length:  5
# Coefficients:  -0.776740385284 Intercept:  684.736890604
# Point one:  (478, 312) Point two:  (960, 585)
# Point one:  (478, 312) Point two:  (0, 684)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8

# %%
plt.plot([305.0, 373.0, 229.0, 302.5, 281.5, 197.5, 445.0, 339.5, 781.5, 346.0, 217.0, 439.5],
         [432.0, 391.0, 497.5, 434.5, 458.5, 521.0, 332.0, 413.5, 492.5, 410.5, 506.5, 336.5])
plt.show()

# %%
plt.plot([730.0, 762.0, 774.0, 730.0],[453.5, 463.0, 469.0, 453.0])
plt.show()

# %%
plt.plot([[ 613.5  396.5]
 [ 603.   386.5]
 [ 627.   406. ]
 [ 592.   379.5]
 [ 780.   492.5]
 [ 567.   364. ]])
# Out:
#   File "<ipython-input-52-d00a7c1ad464>", line 1
#     plt.plot([[ 613.5  396.5]
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Test on Images
#
# Now you should build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
# Out:
# ['solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %%
def read_image(image_path):
    return mpimg.imread(image_path)

# %% [markdown]
# run your solution on all test_images and make copies into the test_images directory).

# %% [markdown]
# ### Pipeline
#
# Steps:
# 1. Read in and grayscale the image
# 2. Define a kernel size and apply Gaussian smoothing
# 3. Define our parameters for Canny and apply to get edges image
# 4. Mask edges image using cv2.fillPoly() (ignore everything outside region of interest)
# 5. Define Hough transform parameters and run Hough transform on masked edge-detected image
# 6. Draw lines

# %%
# Read image
image_path = 'test_images/solidWhiteCurve.jpg'
# image = read_image_and_print_dims(image_path)
image = mpimg.imread(image_path)

# %%
image = test_images[3]

# %%
print("image.shape: ", image.shape)
imshape = image.shape
greyscaled_image = grayscale(image)
plt.imshow(greyscaled_image, cmap="gray")
print("Greyscaled image dims: ", greyscaled_image.shape)
# Out:
# image.shape:  (540, 960, 3)
# Greyscaled image dims:  (540, 960)

# %%
blurred_grey_image = gaussian_blur(greyscaled_image, 5)
edges_image = canny(blurred_grey_image, 50, 150)
# (80,540),(460, 280), (490, 280), (900,540)
vertices = np.array([[(0,imshape[0]),(465, 300), (475, 300), (imshape[1],imshape[0])]], dtype=np.int32)
edges_image_with_mask = region_of_interest(edges_image, vertices)
rho = 2 # distance resolution in pixels of the Hough grid

theta = np.pi/180 # angular resolution in radians of the Hough grid
threshold = 15     # minimum number of votes (intersections in Hough grid cell)
min_line_len = 40 #minimum number of pixels making up a line
max_line_gap = 20    # maximum gap in pixels between connectable line segments
lines_image = hough_lines(edges_image_with_mask, rho, theta, threshold, min_line_len, max_line_gap)
print("Hough output image.shape: ", lines_image.shape)
plt.imshow(lines_image)
# Out:
# Hough output image.shape:  (540, 960)

# %%
hough_rgb_image = cv2.cvtColor(lines_image, cv2.COLOR_GRAY2BGR)
print("hough_rgb.shape: ", hough_rgb_image.shape)
plt.imshow(hough_rgb_image)
# Out:
# hough_rgb.shape:  (540, 960, 3)

# %%
final_image = weighted_img(hough_rgb_image, image)
plt.imshow(final_image)

# %%
border = 80
vertices = np.array([[(0,imshape[0]),(475, 300), (485, 300), 
                      (imshape[1],imshape[0])]], 
                    dtype=np.int32)    
plt.imshow(region_of_interest(test_images[5], vertices))

# %%
help(cv2.fitLine)
# Out:
# Help on built-in function fitLine:
#
# fitLine(...)
#     fitLine(points, distType, param, reps, aeps[, line]) -> line

# %%
filename = str()
cv2.imwrite(filename, img[, params])

# %%
def read_image(image_path):
    return mpimg.imread(image_path)

# %%
image_path = 'test_images/solidWhiteCurve.jpg'

# %%
draw_lane_lines(test_images[0])
# Out:
# Points:  [583, 369, 877, 538]
# Length:  339.11207586873104
# Points:  [626, 388, 898, 538]
# Length:  310.61873736141547
# Points:  [292, 462, 461, 325]
# Length:  217.55459085020476
# Points:  [280, 460, 460, 324]
# Length:  225.6014184352572
# Points:  [651, 401, 897, 537]
# Length:  281.0907326825273
# Points:  [588, 371, 872, 535]
# Length:  327.95121588431414
# Points:  [307, 439, 462, 322]
# Length:  194.20092687729377
# Points:  [351, 410, 468, 322]
# Length:  146.40013661195812
# Points:  [318, 440, 342, 421]
# Length:  30.610455730027933
# Points:  [281, 460, 305, 442]
# Length:  30.0
# Points:  [441, 343, 469, 322]
# Length:  35.0
# positive slope line points:  [[583 369]
#  [877 538]
#  [626 388]
#  [898 538]
#  [651 401]
#  [897 537]
#  [588 371]
#  [872 535]]
# negative slope line points:  [[292 462]
#  [461 325]
#  [280 460]
#  [460 324]
#  [307 439]
#  [462 322]
#  [351 410]
#  [468 322]]
# X points:  [[583], [877], [626], [898], [651], [897], [588], [872]] Length:  8
# X points:  [583, 877, 626, 898, 651, 897, 588, 872] Length:  8
# Y points:  [369, 538, 388, 538, 401, 537, 371, 535] Length:  8
# Coefficients:  0.561016199912 Intercept:  39.4238662662
# X points:  [[292], [461], [280], [460], [307], [462], [351], [468]] Length:  8
# X points:  [292, 461, 280, 460, 307, 462, 351, 468] Length:  8
# Y points:  [462, 325, 460, 324, 439, 322, 410, 322] Length:  8
# Coefficients:  -0.76880089375 Intercept:  679.084444205
# Point one:  (481, 309) Point two:  (960, 577)
# Point one:  (481, 309) Point two:  (0, 679)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8

# %%
draw_lane_lines(test_images[1])
# Out:
# Points:  [550, 354, 822, 531]
# Length:  324.5196450139806
# Points:  [573, 364, 853, 539]
# Length:  330.1893396219811
# Points:  [319, 425, 464, 320]
# Length:  179.02513789968157
# Points:  [310, 423, 460, 322]
# Length:  180.83417818543043
# Points:  [553, 355, 582, 373]
# Length:  34.132096331752024
# Points:  [800, 518, 832, 538]
# Length:  37.73592452822641
# Points:  [362, 392, 453, 326]
# Length:  112.4144118874444
# Points:  [406, 357, 445, 329]
# Length:  48.010415536631214
# Points:  [165, 521, 187, 521]
# Length:  22.0
# Points:  [712, 460, 754, 487]
# Length:  49.92995093127971
# Points:  [551, 354, 719, 463]
# Length:  200.26232796010336
# Points:  [777, 503, 797, 515]
# Length:  23.323807579381203
# Points:  [581, 368, 625, 395]
# Length:  51.62363799656123
# Points:  [316, 425, 394, 372]
# Length:  94.30270409696638
# Points:  [799, 517, 820, 517]
# Length:  21.0
# Points:  [796, 515, 817, 515]
# Length:  21.0
# Points:  [361, 392, 418, 354]
# Length:  68.5054742338158
# Points:  [739, 478, 771, 498]
# Length:  37.73592452822641
# Points:  [809, 510, 853, 538]
# Length:  52.15361924162119
# positive slope line points:  [[550 354]
#  [822 531]
#  [573 364]
#  [853 539]
#  [551 354]
#  [719 463]
#  [581 368]
#  [625 395]
#  [809 510]
#  [853 538]]
# negative slope line points:  [[319 425]
#  [464 320]
#  [310 423]
#  [460 322]
#  [362 392]
#  [453 326]
#  [316 425]
#  [394 372]
#  [361 392]
#  [418 354]]
# X points:  [[550], [822], [573], [853], [551], [719], [581], [625], [809], [853]] Length:  10
# X points:  [550, 822, 573, 853, 551, 719, 581, 625, 809, 853] Length:  10
# Y points:  [354, 531, 364, 539, 354, 463, 368, 395, 510, 538] Length:  10
# Coefficients:  0.627448258324 Intercept:  6.40188802624
# X points:  [[319], [464], [310], [460], [362], [453], [316], [394], [361], [418]] Length:  10
# X points:  [319, 464, 310, 460, 362, 453, 316, 394, 361, 418] Length:  10
# Y points:  [425, 320, 423, 322, 392, 326, 425, 372, 392, 354] Length:  10
# Coefficients:  -0.702096286501 Intercept:  645.898537704
# Point one:  (480, 308) Point two:  (960, 608)
# Point one:  (480, 308) Point two:  (0, 645)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8

# %%
draw_lane_lines(test_images[2])
# Out:
# Coefficients:  0.576842065553 Intercept:  40.9002873364
# Coefficients:  -0.724950612406 Intercept:  659.513670486
# Point one:  (475, 315) Point two:  (960, 594)
# Point one:  (475, 315) Point two:  (0, 659)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8

# %%
draw_lane_lines(test_images[3])
# Out:
# Coefficients:  0.592537726844 Intercept:  26.7315865015
# Coefficients:  -0.715154605472 Intercept:  653.886663723
# Point one:  (479, 310) Point two:  (960, 595)
# Point one:  (479, 310) Point two:  (0, 653)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8

# %%
draw_lane_lines(test_images[4])
# Out:
# Coefficients:  0.611892953527 Intercept:  16.613426024
# Coefficients:  -0.706948166799 Intercept:  644.51275552
# Point one:  (476, 307) Point two:  (960, 604)
# Point one:  (476, 307) Point two:  (0, 644)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8

# %%
draw_lane_lines(test_images[5])
# Out:
# Coefficients:  0.570339671771 Intercept:  38.6318800616
# Coefficients:  -0.76578262862 Intercept:  681.136171765
# Point one:  (480, 312) Point two:  (960, 586)
# Point one:  (480, 312) Point two:  (0, 681)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8

# %%
os.listdir("test_images/")
# Out:
# ['solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %%
test_images = [read_image('test_images/' + i) for i in os.listdir('test_images/')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1b89591fa275> in <module>()
# ----> 1 test_images = [read_image('test_images/' + i) for i in os.listdir('test_images/')]
#
# NameError: name 'os' is not defined

# %%
draw_lane_lines(test_images[3])
# Out:
# Coefficients:  0.592537726844 Intercept:  26.7315865015
# Coefficients:  -0.715154605472 Intercept:  653.886663723
# Point one:  (479, 310) Point two:  (960, 595)
# Point one:  (479, 310) Point two:  (0, 653)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8

# %%
img = cv2.imread('golden_five_pointed_star.jpg', 0)
print("img: ", img)
# img is src
#  threshold(src, thresh, maxval, type[, dst]) -> retval, dst
ret, thresh = cv2.threshold(img, 127, 255, 0)
# ret is retval
print("ret: ", ret)
# thresh is dst
print("thresh: ", thresh)
image, contours, hierarchy = cv2.findContours(thresh, 1, 2)
print("contours: ", contours)
print("hierarchy: ", hierarchy)
cnt = contours[0]
M = cv2.moments(cnt)
print("moments: ", M)
# Out:
# img:  [[255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  ...,
#  [255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]]
# ret:  127.0
# thresh:  [[255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  ...,
#  [255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]]
# contours:  [array([[[209, 311]],
#
#        [[207, 313]],
#
#        [[206, 313]],
#
#        [[204, 315]],
#
#        [[203, 315]],
#
#        [[200, 318]],
#
#        [[199, 318]],
#
#        [[197, 320]],
#
#        [[196, 320]],
#
#        [[194, 322]],
#
#        [[193, 322]],
#
#        [[191, 324]],
#
#        [[190, 324]],
#
#        [[187, 327]],
#
#        [[186, 327]],
#
#        [[184, 329]],
#
#        [[183, 329]],
#
#        [[181, 331]],
#
#        [[180, 331]],
#
#        [[177, 334]],
#
#        [[176, 334]],
#
#        [[174, 336]],
#
#        [[173, 336]],
#
#        [[171, 338]],
#
#        [[170, 338]],
#
#        [[167, 341]],
#
#        [[166, 341]],
#
#        [[164, 343]],
#
#        [[163, 343]],
#
#        [[161, 345]],
#
#        [[160, 345]],
#
#        [[157, 348]],
#
#        [[156, 348]],
#
#        [[154, 350]],
#
#        [[153, 350]],
#
#        [[151, 352]],
#
#        [[150, 352]],
#
#        [[147, 355]],
#
#        [[146, 355]],
#
#        [[144, 357]],
#
#        [[143, 357]],
#
#        [[141, 359]],
#
#        [[140, 359]],
#
#        [[138, 361]],
#
#        [[137, 361]],
#
#        [[134, 364]],
#
#        [[133, 364]],
#
#        [[131, 366]],
#
#        [[130, 366]],
#
#        [[128, 368]],
#
#        [[127, 368]],
#
#        [[124, 371]],
#
#        [[123, 371]],
#
#        [[121, 373]],
#
#        [[120, 373]],
#
#        [[118, 375]],
#
#        [[117, 375]],
#
#        [[114, 378]],
#
#        [[113, 378]],
#
#        [[111, 380]],
#
#        [[110, 380]],
#
#        [[108, 382]],
#
#        [[107, 382]],
#
#        [[104, 385]],
#
#        [[103, 385]],
#
#        [[101, 387]],
#
#        [[100, 387]],
#
#        [[ 98, 389]],
#
#        [[ 97, 389]],
#
#        [[ 95, 391]],
#
#        [[ 94, 391]],
#
#        [[ 91, 394]],
#
#        [[ 90, 394]],
#
#        [[ 88, 396]],
#
#        [[ 87, 396]],
#
#        [[ 85, 398]],
#
#        [[ 84, 398]],
#
#        [[ 83, 399]],
#
#        [[338, 399]],
#
#        [[337, 398]],
#
#        [[336, 398]],
#
#        [[334, 396]],
#
#        [[333, 396]],
#
#        [[331, 394]],
#
#        [[330, 394]],
#
#        [[328, 392]],
#
#        [[327, 392]],
#
#        [[324, 389]],
#
#        [[323, 389]],
#
#        [[321, 387]],
#
#        [[320, 387]],
#
#        [[318, 385]],
#
#        [[317, 385]],
#
#        [[314, 382]],
#
#        [[313, 382]],
#
#        [[311, 380]],
#
#        [[310, 380]],
#
#        [[308, 378]],
#
#        [[307, 378]],
#
#        [[304, 375]],
#
#        [[303, 375]],
#
#        [[301, 373]],
#
#        [[300, 373]],
#
#        [[298, 371]],
#
#        [[297, 371]],
#
#        [[294, 368]],
#
#        [[293, 368]],
#
#        [[291, 366]],
#
#        [[290, 366]],
#
#        [[288, 364]],
#
#        [[287, 364]],
#
#        [[284, 361]],
#
#        [[283, 361]],
#
#        [[281, 359]],
#
#        [[280, 359]],
#
#        [[278, 357]],
#
#        [[277, 357]],
#
#        [[274, 354]],
#
#        [[273, 354]],
#
#        [[271, 352]],
#
#        [[270, 352]],
#
#        [[268, 350]],
#
#        [[267, 350]],
#
#        [[265, 348]],
#
#        [[264, 348]],
#
#        [[261, 345]],
#
#        [[260, 345]],
#
#        [[258, 343]],
#
#        [[257, 343]],
#
#        [[255, 341]],
#
#        [[254, 341]],
#
#        [[251, 338]],
#
#        [[250, 338]],
#
#        [[248, 336]],
#
#        [[247, 336]],
#
#        [[245, 334]],
#
#        [[244, 334]],
#
#        [[241, 331]],
#
#        [[240, 331]],
#
#        [[238, 329]],
#
#        [[237, 329]],
#
#        [[235, 327]],
#
#        [[234, 327]],
#
#        [[231, 324]],
#
#        [[230, 324]],
#
#        [[228, 322]],
#
#        [[227, 322]],
#
#        [[225, 320]],
#
#        [[224, 320]],
#
#        [[222, 318]],
#
#        [[221, 318]],
#
#        [[218, 315]],
#
#        [[217, 315]],
#
#        [[215, 313]],
#
#        [[214, 313]],
#
#        [[212, 311]]], dtype=int32), array([[[419, 154]],
#
#        [[416, 157]],
#
#        [[415, 157]],
#
#        [[412, 160]],
#
#        [[411, 160]],
#
#        [[408, 163]],
#
#        [[407, 163]],
#
#        [[404, 166]],
#
#        [[403, 166]],
#
#        [[400, 169]],
#
#        [[399, 169]],
#
#        [[396, 172]],
#
#        [[395, 172]],
#
#        [[392, 175]],
#
#        [[391, 175]],
#
#        [[388, 178]],
#
#        [[387, 178]],
#
#        [[384, 181]],
#
#        [[383, 181]],
#
#        [[380, 184]],
#
#        [[379, 184]],
#
#        [[376, 187]],
#
#        [[375, 187]],
#
#        [[372, 190]],
#
#        [[371, 190]],
#
#        [[368, 193]],
#
#        [[367, 193]],
#
#        [[364, 196]],
#
#        [[363, 196]],
#
#        [[360, 199]],
#
#        [[359, 199]],
#
#        [[356, 202]],
#
#        [[355, 202]],
#
#        [[352, 205]],
#
#        [[351, 205]],
#
#        [[348, 208]],
#
#        [[347, 208]],
#
#        [[344, 211]],
#
#        [[343, 211]],
#
#        [[340, 214]],
#
#        [[339, 214]],
#
#        [[336, 217]],
#
#        [[335, 217]],
#
#        [[332, 220]],
#
#        [[331, 220]],
#
#        [[328, 223]],
#
#        [[327, 223]],
#
#        [[324, 226]],
#
#        [[323, 226]],
#
#        [[320, 229]],
#
#        [[319, 229]],
#
#        [[316, 232]],
#
#        [[315, 232]],
#
#        [[312, 235]],
#
#        [[311, 235]],
#
#        [[308, 238]],
#
#        [[307, 238]],
#
#        [[304, 241]],
#
#        [[303, 241]],
#
#        [[300, 244]],
#
#        [[299, 244]],
#
#        [[296, 247]],
#
#        [[295, 247]],
#
#        [[294, 248]],
#
#        [[294, 249]],
#
#        [[295, 250]],
#
#        [[295, 252]],
#
#        [[296, 253]],
#
#        [[296, 255]],
#
#        [[297, 256]],
#
#        [[297, 258]],
#
#        [[298, 259]],
#
#        [[298, 262]],
#
#        [[299, 263]],
#
#        [[299, 265]],
#
#        [[300, 266]],
#
#        [[300, 268]],
#
#        [[301, 269]],
#
#        [[301, 272]],
#
#        [[302, 273]],
#
#        [[302, 275]],
#
#        [[303, 276]],
#
#        [[303, 278]],
#
#        [[304, 279]],
#
#        [[304, 282]],
#
#        [[305, 283]],
#
#        [[305, 285]],
#
#        [[306, 286]],
#
#        [[306, 288]],
#
#        [[307, 289]],
#
#        [[307, 291]],
#
#        [[308, 292]],
#
#        [[308, 295]],
#
#        [[309, 296]],
#
#        [[309, 298]],
#
#        [[310, 299]],
#
#        [[310, 301]],
#
#        [[311, 302]],
#
#        [[311, 305]],
#
#        [[312, 306]],
#
#        [[312, 308]],
#
#        [[313, 309]],
#
#        [[313, 311]],
#
#        [[314, 312]],
#
#        [[314, 315]],
#
#        [[315, 316]],
#
#        [[315, 318]],
#
#        [[316, 319]],
#
#        [[316, 321]],
#
#        [[317, 322]],
#
#        [[317, 325]],
#
#        [[318, 326]],
#
#        [[318, 328]],
#
#        [[319, 329]],
#
#        [[319, 331]],
#
#        [[320, 332]],
#
#        [[320, 334]],
#
#        [[321, 335]],
#
#        [[321, 338]],
#
#        [[322, 339]],
#
#        [[322, 341]],
#
#        [[323, 342]],
#
#        [[323, 344]],
#
#        [[324, 345]],
#
#        [[324, 348]],
#
#        [[325, 349]],
#
#        [[325, 351]],
#
#        [[326, 352]],
#
#        [[326, 354]],
#
#        [[327, 355]],
#
#        [[327, 358]],
#
#        [[328, 359]],
#
#        [[328, 361]],
#
#        [[329, 362]],
#
#        [[329, 364]],
#
#        [[330, 365]],
#
#        [[330, 367]],
#
#        [[331, 368]],
#
#        [[331, 371]],
#
#        [[332, 372]],
#
#        [[332, 374]],
#
#        [[333, 375]],
#
#        [[333, 377]],
#
#        [[334, 378]],
#
#        [[334, 381]],
#
#        [[335, 382]],
#
#        [[335, 384]],
#
#        [[336, 385]],
#
#        [[336, 387]],
#
#        [[337, 388]],
#
#        [[337, 391]],
#
#        [[338, 392]],
#
#        [[338, 394]],
#
#        [[339, 395]],
#
#        [[339, 397]],
#
#        [[340, 398]],
#
#        [[340, 399]],
#
#        [[420, 399]],
#
#        [[420, 154]]], dtype=int32), array([[[  1, 154]],
#
#        [[  1, 399]],
#
#        [[ 81, 399]],
#
#        [[ 81, 398]],
#
#        [[ 82, 397]],
#
#        [[ 82, 395]],
#
#        [[ 83, 394]],
#
#        [[ 83, 392]],
#
#        [[ 84, 391]],
#
#        [[ 84, 388]],
#
#        [[ 85, 387]],
#
#        [[ 85, 385]],
#
#        [[ 86, 384]],
#
#        [[ 86, 382]],
#
#        [[ 87, 381]],
#
#        [[ 87, 378]],
#
#        [[ 88, 377]],
#
#        [[ 88, 375]],
#
#        [[ 89, 374]],
#
#        [[ 89, 372]],
#
#        [[ 90, 371]],
#
#        [[ 90, 368]],
#
#        [[ 91, 367]],
#
#        [[ 91, 365]],
#
#        [[ 92, 364]],
#
#        [[ 92, 362]],
#
#        [[ 93, 361]],
#
#        [[ 93, 359]],
#
#        [[ 94, 358]],
#
#        [[ 94, 355]],
#
#        [[ 95, 354]],
#
#        [[ 95, 352]],
#
#        [[ 96, 351]],
#
#        [[ 96, 349]],
#
#        [[ 97, 348]],
#
#        [[ 97, 345]],
#
#        [[ 98, 344]],
#
#        [[ 98, 342]],
#
#        [[ 99, 341]],
#
#        [[ 99, 339]],
#
#        [[100, 338]],
#
#        [[100, 335]],
#
#        [[101, 334]],
#
#        [[101, 332]],
#
#        [[102, 331]],
#
#        [[102, 329]],
#
#        [[103, 328]],
#
#        [[103, 326]],
#
#        [[104, 325]],
#
#        [[104, 322]],
#
#        [[105, 321]],
#
#        [[105, 319]],
#
#        [[106, 318]],
#
#        [[106, 316]],
#
#        [[107, 315]],
#
#        [[107, 312]],
#
#        [[108, 311]],
#
#        [[108, 309]],
#
#        [[109, 308]],
#
#        [[109, 306]],
#
#        [[110, 305]],
#
#        [[110, 302]],
#
#        [[111, 301]],
#
#        [[111, 299]],
#
#        [[112, 298]],
#
#        [[112, 296]],
#
#        [[113, 295]],
#
#        [[113, 292]],
#
#        [[114, 291]],
#
#        [[114, 289]],
#
#        [[115, 288]],
#
#        [[115, 286]],
#
#        [[116, 285]],
#
#        [[116, 283]],
#
#        [[117, 282]],
#
#        [[117, 279]],
#
#        [[118, 278]],
#
#        [[118, 276]],
#
#        [[119, 275]],
#
#        [[119, 273]],
#
#        [[120, 272]],
#
#        [[120, 269]],
#
#        [[121, 268]],
#
#        [[121, 266]],
#
#        [[122, 265]],
#
#        [[122, 263]],
#
#        [[123, 262]],
#
#        [[123, 259]],
#
#        [[124, 258]],
#
#        [[124, 256]],
#
#        [[125, 255]],
#
#        [[125, 253]],
#
#        [[126, 252]],
#
#        [[126, 249]],
#
#        [[127, 248]],
#
#        [[126, 247]],
#
#        [[125, 247]],
#
#        [[122, 244]],
#
#        [[121, 244]],
#
#        [[118, 241]],
#
#        [[117, 241]],
#
#        [[114, 238]],
#
#        [[113, 238]],
#
#        [[110, 235]],
#
#        [[109, 235]],
#
#        [[106, 232]],
#
#        [[105, 232]],
#
#        [[102, 229]],
#
#        [[101, 229]],
#
#        [[ 98, 226]],
#
#        [[ 97, 226]],
#
#        [[ 94, 223]],
#
#        [[ 93, 223]],
#
#        [[ 90, 220]],
#
#        [[ 89, 220]],
#
#        [[ 86, 217]],
#
#        [[ 85, 217]],
#
#        [[ 82, 214]],
#
#        [[ 81, 214]],
#
#        [[ 78, 211]],
#
#        [[ 77, 211]],
#
#        [[ 74, 208]],
#
#        [[ 73, 208]],
#
#        [[ 70, 205]],
#
#        [[ 69, 205]],
#
#        [[ 66, 202]],
#
#        [[ 65, 202]],
#
#        [[ 62, 199]],
#
#        [[ 61, 199]],
#
#        [[ 58, 196]],
#
#        [[ 57, 196]],
#
#        [[ 54, 193]],
#
#        [[ 53, 193]],
#
#        [[ 50, 190]],
#
#        [[ 49, 190]],
#
#        [[ 46, 187]],
#
#        [[ 45, 187]],
#
#        [[ 42, 184]],
#
#        [[ 41, 184]],
#
#        [[ 38, 181]],
#
#        [[ 37, 181]],
#
#        [[ 34, 178]],
#
#        [[ 33, 178]],
#
#        [[ 30, 175]],
#
#        [[ 29, 175]],
#
#        [[ 26, 172]],
#
#        [[ 25, 172]],
#
#        [[ 22, 169]],
#
#        [[ 21, 169]],
#
#        [[ 18, 166]],
#
#        [[ 17, 166]],
#
#        [[ 14, 163]],
#
#        [[ 13, 163]],
#
#        [[ 10, 160]],
#
#        [[  9, 160]],
#
#        [[  6, 157]],
#
#        [[  5, 157]],
#
#        [[  2, 154]]], dtype=int32), array([[[210,  28]],
#
#        [[210,  30]],
#
#        [[209,  31]],
#
#        ...,
#        [[212,  31]],
#
#        [[211,  30]],
#
#        [[211,  28]]], dtype=int32), array([[[  1,   1]],
#
#        [[  1, 152]],
#
#        [[158, 152]],
#
#        [[159, 151]],
#
#        [[159, 150]],
#
#        [[160, 149]],
#
#        [[160, 147]],
#
#        [[161, 146]],
#
#        [[161, 144]],
#
#        [[162, 143]],
#
#        [[162, 141]],
#
#        [[163, 140]],
#
#        [[163, 138]],
#
#        [[164, 137]],
#
#        [[164, 135]],
#
#        [[165, 134]],
#
#        [[165, 133]],
#
#        [[166, 132]],
#
#        [[166, 130]],
#
#        [[167, 129]],
#
#        [[167, 127]],
#
#        [[168, 126]],
#
#        [[168, 124]],
#
#        [[169, 123]],
#
#        [[169, 121]],
#
#        [[170, 120]],
#
#        [[170, 118]],
#
#        [[171, 117]],
#
#        [[171, 115]],
#
#        [[172, 114]],
#
#        [[172, 112]],
#
#        [[173, 111]],
#
#        [[173, 109]],
#
#        [[174, 108]],
#
#        [[174, 106]],
#
#        [[175, 105]],
#
#        [[175, 103]],
#
#        [[176, 102]],
#
#        [[176, 100]],
#
#        [[177,  99]],
#
#        [[177,  97]],
#
#        [[178,  96]],
#
#        [[178,  94]],
#
#        [[179,  93]],
#
#        [[179,  91]],
#
#        [[180,  90]],
#
#        [[180,  88]],
#
#        [[181,  87]],
#
#        [[181,  85]],
#
#        [[182,  84]],
#
#        [[182,  82]],
#
#        [[183,  81]],
#
#        [[183,  79]],
#
#        [[184,  78]],
#
#        [[184,  76]],
#
#        [[185,  75]],
#
#        [[185,  73]],
#
#        [[186,  72]],
#
#        [[186,  70]],
#
#        [[187,  69]],
#
#        [[187,  67]],
#
#        [[188,  66]],
#
#        [[188,  64]],
#
#        [[189,  63]],
#
#        [[189,  61]],
#
#        [[190,  60]],
#
#        [[190,  58]],
#
#        [[191,  57]],
#
#        [[191,  55]],
#
#        [[192,  54]],
#
#        [[192,  52]],
#
#        [[193,  51]],
#
#        [[193,  50]],
#
#        [[194,  49]],
#
#        [[194,  47]],
#
#        [[195,  46]],
#
#        [[195,  44]],
#
#        [[196,  43]],
#
#        [[196,  41]],
#
#        [[197,  40]],
#
#        [[197,  38]],
#
#        [[198,  37]],
#
#        [[198,  35]],
#
#        [[199,  34]],
#
#        [[199,  32]],
#
#        [[200,  31]],
#
#        [[200,  29]],
#
#        [[201,  28]],
#
#        [[201,  26]],
#
#        [[202,  25]],
#
#        [[202,  23]],
#
#        [[203,  22]],
#
#        [[203,  20]],
#
#        [[204,  19]],
#
#        [[204,  17]],
#
#        [[205,  16]],
#
#        [[205,  14]],
#
#        [[206,  13]],
#
#        [[206,  11]],
#
#        [[207,  10]],
#
#        [[207,   8]],
#
#        [[208,   7]],
#
#        [[208,   5]],
#
#        [[209,   4]],
#
#        [[209,   2]],
#
#        [[210,   1]],
#
#        [[211,   1]],
#
#        [[212,   2]],
#
#        [[212,   4]],
#
#        [[213,   5]],
#
#        [[213,   7]],
#
#        [[214,   8]],
#
#        [[214,  10]],
#
#        [[215,  11]],
#
#        [[215,  13]],
#
#        [[216,  14]],
#
#        [[216,  16]],
#
#        [[217,  17]],
#
#        [[217,  19]],
#
#        [[218,  20]],
#
#        [[218,  22]],
#
#        [[219,  23]],
#
#        [[219,  25]],
#
#        [[220,  26]],
#
#        [[220,  28]],
#
#        [[221,  29]],
#
#        [[221,  31]],
#
#        [[222,  32]],
#
#        [[222,  34]],
#
#        [[223,  35]],
#
#        [[223,  37]],
#
#        [[224,  38]],
#
#        [[224,  40]],
#
#        [[225,  41]],
#
#        [[225,  43]],
#
#        [[226,  44]],
#
#        [[226,  46]],
#
#        [[227,  47]],
#
#        [[227,  49]],
#
#        [[228,  50]],
#
#        [[228,  51]],
#
#        [[229,  52]],
#
#        [[229,  54]],
#
#        [[230,  55]],
#
#        [[230,  57]],
#
#        [[231,  58]],
#
#        [[231,  60]],
#
#        [[232,  61]],
#
#        [[232,  63]],
#
#        [[233,  64]],
#
#        [[233,  66]],
#
#        [[234,  67]],
#
#        [[234,  69]],
#
#        [[235,  70]],
#
#        [[235,  72]],
#
#        [[236,  73]],
#
#        [[236,  75]],
#
#        [[237,  76]],
#
#        [[237,  78]],
#
#        [[238,  79]],
#
#        [[238,  81]],
#
#        [[239,  82]],
#
#        [[239,  84]],
#
#        [[240,  85]],
#
#        [[240,  87]],
#
#        [[241,  88]],
#
#        [[241,  90]],
#
#        [[242,  91]],
#
#        [[242,  93]],
#
#        [[243,  94]],
#
#        [[243,  96]],
#
#        [[244,  97]],
#
#        [[244,  99]],
#
#        [[245, 100]],
#
#        [[245, 102]],
#
#        [[246, 103]],
#
#        [[246, 105]],
#
#        [[247, 106]],
#
#        [[247, 108]],
#
#        [[248, 109]],
#
#        [[248, 111]],
#
#        [[249, 112]],
#
#        [[249, 114]],
#
#        [[250, 115]],
#
#        [[250, 117]],
#
#        [[251, 118]],
#
#        [[251, 120]],
#
#        [[252, 121]],
#
#        [[252, 123]],
#
#        [[253, 124]],
#
#        [[253, 126]],
#
#        [[254, 127]],
#
#        [[254, 129]],
#
#        [[255, 130]],
#
#        [[255, 131]],
#
#        [[256, 132]],
#
#        [[256, 134]],
#
#        [[257, 135]],
#
#        [[257, 137]],
#
#        [[258, 138]],
#
#        [[258, 140]],
#
#        [[259, 141]],
#
#        [[259, 143]],
#
#        [[260, 144]],
#
#        [[260, 146]],
#
#        [[261, 147]],
#
#        [[261, 149]],
#
#        [[262, 150]],
#
#        [[262, 151]],
#
#        [[263, 152]],
#
#        [[420, 152]],
#
#        [[420,   1]]], dtype=int32)]
# hierarchy:  [[[ 1 -1 -1 -1]
#   [ 2  0 -1 -1]
#   [ 3  1 -1 -1]
#   [ 4  2 -1 -1]
#   [-1  3 -1 -1]]]
# moments:  {'nu02': 0.03875855269827929, 'm01': 4174944.6666666665, 'm12': 325669444758.5, 'm20': 531282385.6666666, 'm02': 1547170170.6666665, 'mu02': 4950831.635659456, 'mu20': 30510252.918126523, 'm30': 124676085177.0, 'nu30': -6.59751037837835e-05, 'mu21': 361287975.00870895, 'm03': 575121862229.2001, 'nu03': -0.0043098406118258934, 'nu11': -2.7563789519896753e-05, 'nu21': 0.026605121677095982, 'mu30': -895918.1595306396, 'm10': 2379018.0, 'm21': 196614854611.4, 'm11': 878802753.3333333, 'nu20': 0.2388554757240339, 'mu03': -58526084.04333496, 'm00': 11302.0, 'mu12': -19604.913405537605, 'mu11': -3520.8662773370743, 'nu12': -1.4436990509044344e-06}

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image with lines are drawn on lanes)
    result = draw_lane_lines(image)
    print(result.shape)
    return result

# %%
process_image(image)
# Out:
# Coefficients:  0.570339671771 Intercept:  38.6318800616
# Coefficients:  -0.76578262862 Intercept:  681.136171765
# Point one:  (480, 312) Point two:  (960, 586)
# Point one:  (480, 312) Point two:  (0, 681)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# array([[[ 88, 127, 162],
#         [ 88, 127, 162],
#         [ 88, 127, 162],
#         ...,
#         [ 81, 124, 161],
#         [ 80, 123, 160],
#         [ 75, 118, 155]],
#
#        [[ 88, 127, 162],
#         [ 88, 127, 162],
#         [ 88, 127, 162],
#         ...,
#         [ 81, 124, 161],
#         [ 80, 123, 160],
#         [ 75, 118, 155]],
#
#        [[ 88, 127, 162],
#         [ 88, 127, 162],
#         [ 88, 127, 162],
#         ...,
#         [ 81, 124, 161],
#         [ 80, 123, 160],
#         [ 75, 118, 155]],
#
#        ...,
#        [[ 76,  80,  85],
#         [ 75,  79,  84],
#         [ 75,  79,  84],
#         ...,
#         [ 67,  70,  82],
#         [ 66,  68,  80],
#         [ 63,  66,  78]],
#
#        [[ 75,  79,  84],
#         [ 75,  79,  84],
#         [ 74,  78,  83],
#         ...,
#         [ 67,  70,  80],
#         [ 66,  69,  78],
#         [ 62,  66,  75]],
#
#        [[ 72,  78,  82],
#         [ 71,  77,  82],
#         [ 71,  77,  82],
#         ...,
#         [ 66,  70,  79],
#         [ 65,  68,  78],
#         [ 62,  66,  75]]], dtype=uint8)

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'white.mp4'
clip1 = VideoFileClip("solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# Coefficients:  0.612404179964 Intercept:  12.2849386577
# Coefficients:  -0.738324111582 Intercept:  657.451152299
# Point one:  (477, 304) Point two:  (960, 600)
# Point one:  (477, 304) Point two:  (0, 657)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# [MoviePy] >>>> Building video white.mp4
# [MoviePy] Writing video white.mp4
#   1%|▏         | 3/222 [00:00<00:09, 22.45it/s]
# Coefficients:  0.612404179964 Intercept:  12.2849386577
# Coefficients:  -0.738324111582 Intercept:  657.451152299
# Point one:  (477, 304) Point two:  (960, 600)
# Point one:  (477, 304) Point two:  (0, 657)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.620650180241 Intercept:  5.82659812855
# Coefficients:  -0.73360237326 Intercept:  655.449681698
# Point one:  (479, 303) Point two:  (960, 601)
# Point one:  (479, 303) Point two:  (0, 655)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.620192170936 Intercept:  7.91636231333
# Coefficients:  -0.743567699958 Intercept:  659.194880137
# Point one:  (477, 304) Point two:  (960, 603)
# Point one:  (477, 304) Point two:  (0, 659)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.611947111984 Intercept:  13.8534570423
# Coefficients:  -0.73336542164 Intercept:  654.894387755
# Point one:  (476, 305) Point two:  (960, 601)
# Point one:  (476, 305) Point two:  (0, 654)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.607081023769 Intercept:  16.7408970728
# Coefficients:  -0.711671231313 Intercept:  646.190887824
# Point one:  (477, 306) Point two:  (960, 599)
# Point one:  (477, 306) Point two:  (0, 646)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#   3%|▎         | 6/222 [00:00<00:09, 22.50it/s]
# Coefficients:  0.617522144857 Intercept:  9.43213845577
# Coefficients:  -0.704376040605 Intercept:  643.026293941
# Point one:  (479, 305) Point two:  (960, 602)
# Point one:  (479, 305) Point two:  (0, 643)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.620823055491 Intercept:  6.39737537932
# Coefficients:  -0.706294458958 Intercept:  643.789923778
# Point one:  (480, 304) Point two:  (960, 602)
# Point one:  (480, 304) Point two:  (0, 643)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.596410879378 Intercept:  20.5524115443
# Coefficients:  -0.714163319579 Intercept:  647.023351931
# Point one:  (478, 305) Point two:  (960, 593)
# Point one:  (478, 305) Point two:  (0, 647)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.607772246739 Intercept:  16.0061061801
# Coefficients:  -0.735350256803 Intercept:  654.998782838
# Point one:  (475, 305) Point two:  (960, 599)
# Point one:  (475, 305) Point two:  (0, 654)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#   4%|▍         | 9/222 [00:00<00:09, 23.06it/s]
# (540, 960, 3)
# Coefficients:  0.608897236064 Intercept:  16.7866436471
# Coefficients:  -0.712643157163 Intercept:  649.088471451
# Point one:  (478, 308) Point two:  (960, 601)
# Point one:  (478, 308) Point two:  (0, 649)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#   5%|▌         | 12/222 [00:00<00:08, 23.36it/s]
# Coefficients:  0.61221227724 Intercept:  17.6558096946
# Coefficients:  -0.703328629534 Intercept:  646.668207853
# Point one:  (478, 310) Point two:  (960, 605)
# Point one:  (478, 310) Point two:  (0, 646)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.624456968416 Intercept:  10.5040360456
# Coefficients:  -0.726410033348 Intercept:  656.121886327
# Point one:  (477, 308) Point two:  (960, 609)
# Point one:  (477, 308) Point two:  (0, 656)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.624139623317 Intercept:  11.3422833085
# Coefficients:  -0.715429951835 Intercept:  650.297785556
# Point one:  (476, 309) Point two:  (960, 610)
# Point one:  (476, 309) Point two:  (0, 650)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.621730660384 Intercept:  9.75735478011
# Coefficients:  -0.719720294004 Intercept:  650.653011776
# Point one:  (477, 306) Point two:  (960, 606)
# Point one:  (477, 306) Point two:  (0, 650)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.636943520062 Intercept:  0.178572458461
# Coefficients:  -0.715069855136 Intercept:  646.696854636
# Point one:  (478, 304) Point two:  (960, 611)
# Point one:  (478, 304) Point two:  (0, 646)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#   7%|▋         | 15/222 [00:00<00:08, 23.77it/s]
# (540, 960, 3)
# Coefficients:  0.62938338209 Intercept:  3.62087306713
#   8%|▊         | 18/222 [00:00<00:08, 23.45it/s]
# Coefficients:  -0.711779064893 Intercept:  643.022810137
# Point one:  (476, 303) Point two:  (960, 607)
# Point one:  (476, 303) Point two:  (0, 643)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.623811315864 Intercept:  5.10437848287
# Coefficients:  -0.696789536266 Intercept:  637.913198573
# Point one:  (479, 304) Point two:  (960, 603)
# Point one:  (479, 304) Point two:  (0, 637)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.6370134226 Intercept:  -2.15171684674
# Coefficients:  -0.677342641249 Intercept:  629.93765103
# Point one:  (480, 304) Point two:  (960, 609)
# Point one:  (480, 304) Point two:  (0, 629)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.645275586882 Intercept:  -3.38185907372
# Coefficients:  -0.697660728417 Intercept:  639.710959063
# Point one:  (478, 305) Point two:  (960, 616)
# Point one:  (478, 305) Point two:  (0, 639)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.639545795506 Intercept:  -0.651970514059
# Coefficients:  -0.711720438119 Intercept:  647.715110647
# Point one:  (479, 306) Point two:  (960, 613)
# Point one:  (479, 306) Point two:  (0, 647)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#   9%|▉         | 21/222 [00:00<00:08, 23.44it/s]
# Coefficients:  0.639965306588 Intercept:  0.437650524232
# Coefficients:  -0.702616710696 Intercept:  645.55891295
# Point one:  (480, 307) Point two:  (960, 614)
# Point one:  (480, 307) Point two:  (0, 645)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.635615361863 Intercept:  2.84758477501
# Coefficients:  -0.685026657837 Intercept:  637.804826607
# Point one:  (480, 308) Point two:  (960, 613)
# Point one:  (480, 308) Point two:  (0, 637)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.630903678019 Intercept:  4.92325463724
# Coefficients:  -0.705347504569 Intercept:  646.269006821
# Point one:  (479, 307) Point two:  (960, 610)
# Point one:  (479, 307) Point two:  (0, 646)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.620700333881 Intercept:  11.7222186343
# Coefficients:  -0.713384984999 Intercept:  649.486878255
# Point one:  (478, 308) Point two:  (960, 607)
# Point one:  (478, 308) Point two:  (0, 649)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  11%|█         | 24/222 [00:01<00:08, 23.79it/s]
# (540, 960, 3)
# Coefficients:  0.627548139081 Intercept:  7.2358148455
# Coefficients:  -0.711546688723 Intercept:  647.489784762
# Point one:  (478, 307) Point two:  (960, 609)
# Point one:  (478, 307) Point two:  (0, 647)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.646550358702 Intercept:  -5.34747022081
# Coefficients:  -0.70441403539 Intercept:  645.194429335
# Point one:  (481, 305) Point two:  (960, 615)
# Point one:  (481, 305) Point two:  (0, 645)
#  12%|█▏        | 27/222 [00:01<00:08, 24.04it/s]
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.630508912604 Intercept:  6.03117491517
# Coefficients:  -0.704825361859 Intercept:  646.014627472
# Point one:  (479, 308) Point two:  (960, 611)
# Point one:  (479, 308) Point two:  (0, 646)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.63478123546 Intercept:  2.68500744882
# Coefficients:  -0.717772438454 Intercept:  649.546754015
# Point one:  (478, 306) Point two:  (960, 612)
# Point one:  (478, 306) Point two:  (0, 649)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.646210796905 Intercept:  -5.63889386006
# Coefficients:  -0.713806342578 Intercept:  648.92018811
# Point one:  (481, 305) Point two:  (960, 614)
# Point one:  (481, 305) Point two:  (0, 648)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  14%|█▎        | 30/222 [00:01<00:07, 24.49it/s]
# Coefficients:  0.634265799401 Intercept:  2.39156123384
# Coefficients:  -0.719803653335 Intercept:  650.741755854
# Point one:  (478, 306) Point two:  (960, 611)
# Point one:  (478, 306) Point two:  (0, 650)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.636173451428 Intercept:  0.636609839408
# Coefficients:  -0.715687162852 Intercept:  648.410890222
# Point one:  (479, 305) Point two:  (960, 611)
# Point one:  (479, 305) Point two:  (0, 648)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  15%|█▍        | 33/222 [00:01<00:07, 24.35it/s]
# (540, 960, 3)
# Coefficients:  0.630103550051 Intercept:  2.62190845422
# Coefficients:  -0.703946184305 Intercept:  644.015984971
# Point one:  (480, 305) Point two:  (960, 607)
# Point one:  (480, 305) Point two:  (0, 644)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.633100841939 Intercept:  -0.024362478547
# Coefficients:  -0.704378636695 Intercept:  642.914603265
# Point one:  (480, 304) Point two:  (960, 607)
# Point one:  (480, 304) Point two:  (0, 642)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.624258335521 Intercept:  5.83911037768
# Coefficients:  -0.720421773612 Intercept:  651.309571017
# Point one:  (480, 305) Point two:  (960, 605)
# Point one:  (480, 305) Point two:  (0, 651)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.632340912497 Intercept:  2.28178357833
# Coefficients:  -0.720372569587 Intercept:  650.484215699
# Point one:  (479, 305) Point two:  (960, 609)
# Point one:  (479, 305) Point two:  (0, 650)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.63018792089 Intercept:  5.46433351671
# Coefficients:  -0.716881968618 Intercept:  649.6991969
# Point one:  (478, 306) Point two:  (960, 610)
# Point one:  (478, 306) Point two:  (0, 649)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  18%|█▊        | 39/222 [00:01<00:07, 24.03it/s]
# (540, 960, 3)
# Coefficients:  0.636029678616 Intercept:  2.98143876769
# Coefficients:  -0.718217626357 Intercept:  650.900358883
# Point one:  (478, 307) Point two:  (960, 613)
# Point one:  (478, 307) Point two:  (0, 650)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.628593960996 Intercept:  6.55960190432
# Coefficients:  -0.709638931137 Intercept:  647.444753119
# Point one:  (478, 307) Point two:  (960, 610)
# Point one:  (478, 307) Point two:  (0, 647)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.629279472217 Intercept:  5.84350423594
# Coefficients:  -0.718522670258 Intercept:  650.420157733
# Point one:  (478, 306) Point two:  (960, 609)
# Point one:  (478, 306) Point two:  (0, 650)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.644755862576 Intercept:  -4.91261591758
# Coefficients:  -0.720658394215 Intercept:  649.629576384
# Point one:  (479, 304) Point two:  (960, 614)
# Point one:  (479, 304) Point two:  (0, 649)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.63867759138 Intercept:  0.331966521672
# Coefficients:  -0.728248626217 Intercept:  652.517650546
# Point one:  (477, 305) Point two:  (960, 613)
# Point one:  (477, 305) Point two:  (0, 652)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  19%|█▉        | 42/222 [00:01<00:07, 23.38it/s]
# (540, 960, 3)
# Coefficients:  0.638991377626 Intercept:  -2.14003698474
# Coefficients:  -0.732793221347 Intercept:  653.587735989
# Point one:  (478, 303) Point two:  (960, 611)
# Point one:  (478, 303) Point two:  (0, 653)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.660370440862 Intercept:  -13.9520334457
# Coefficients:  -0.724126398834 Intercept:  648.646400549
# Point one:  (478, 302) Point two:  (960, 620)
# Point one:  (478, 302) Point two:  (0, 648)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.650479038382 Intercept:  -7.16655436643
# Coefficients:  -0.721068775681 Intercept:  647.523692072
# Point one:  (477, 303) Point two:  (960, 617)
# Point one:  (477, 303) Point two:  (0, 647)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  20%|██        | 45/222 [00:01<00:07, 23.26it/s]
# (540, 960, 3)
# Coefficients:  0.642442213848 Intercept:  -2.57098015039
# Coefficients:  -0.711489945274 Intercept:  644.02975233
# Point one:  (477, 304) Point two:  (960, 614)
# Point one:  (477, 304) Point two:  (0, 644)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.642739017616 Intercept:  -3.40593249762
# Coefficients:  -0.719207943891 Intercept:  647.155255829
# Point one:  (477, 303) Point two:  (960, 613)
# Point one:  (477, 303) Point two:  (0, 647)
#  22%|██▏       | 48/222 [00:02<00:07, 23.41it/s]
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.643650267485 Intercept:  -4.20414670686
# Coefficients:  -0.718891565684 Intercept:  646.848225701
# Point one:  (477, 303) Point two:  (960, 613)
# Point one:  (477, 303) Point two:  (0, 646)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.653747324141 Intercept:  -11.399599042
# Coefficients:  -0.733747174601 Intercept:  652.039727818
# Point one:  (478, 301) Point two:  (960, 616)
# Point one:  (478, 301) Point two:  (0, 652)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.654576439919 Intercept:  -11.5443976681
# Coefficients:  -0.714468322818 Intercept:  644.650910226
# Point one:  (479, 302) Point two:  (960, 616)
# Point one:  (479, 302) Point two:  (0, 644)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.644236304257 Intercept:  -5.75652055936
# Coefficients:  -0.719840251034 Intercept:  647.717558123
# Point one:  (479, 302) Point two:  (960, 612)
# Point one:  (479, 302) Point two:  (0, 647)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  23%|██▎       | 51/222 [00:02<00:07, 23.32it/s]
# Coefficients:  0.644469611812 Intercept:  -6.44701189158
# Coefficients:  -0.707375324369 Intercept:  642.209113837
# Point one:  (479, 302) Point two:  (960, 612)
# Point one:  (479, 302) Point two:  (0, 642)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.658856673688 Intercept:  -14.8529055325
# Coefficients:  -0.706863748674 Intercept:  641.138994329
# Point one:  (480, 301) Point two:  (960, 617)
# Point one:  (480, 301) Point two:  (0, 641)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.645380245653 Intercept:  -6.35439154351
# Coefficients:  -0.695416771594 Intercept:  635.505666079
# Point one:  (478, 302) Point two:  (960, 613)
# Point one:  (478, 302) Point two:  (0, 635)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  24%|██▍       | 54/222 [00:02<00:07, 22.76it/s]
# Coefficients:  0.632226956126 Intercept:  2.74854454421
# Coefficients:  -0.6948951237 Intercept:  636.29448279
# Point one:  (477, 304) Point two:  (960, 609)
# Point one:  (477, 304) Point two:  (0, 636)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.639589011172 Intercept:  -1.47203382778
# Coefficients:  -0.691498015494 Intercept:  634.983092117
# Point one:  (478, 304) Point two:  (960, 612)
# Point one:  (478, 304) Point two:  (0, 634)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  26%|██▌       | 57/222 [00:02<00:07, 22.52it/s]
# Coefficients:  0.625014994117 Intercept:  7.48165694413
# Coefficients:  -0.677614276088 Intercept:  630.076151455
# Point one:  (477, 306) Point two:  (960, 607)
# Point one:  (477, 306) Point two:  (0, 630)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.630054092631 Intercept:  7.09502227736
# Coefficients:  -0.67898450398 Intercept:  631.726876103
# Point one:  (477, 307) Point two:  (960, 611)
# Point one:  (477, 307) Point two:  (0, 631)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.64232267117 Intercept:  -0.900787221719
# Coefficients:  -0.670270353873 Intercept:  628.925977481
# Point one:  (479, 307) Point two:  (960, 615)
# Point one:  (479, 307) Point two:  (0, 628)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  27%|██▋       | 60/222 [00:02<00:07, 22.57it/s]
# Coefficients:  0.652972613239 Intercept:  -7.60061882498
# Coefficients:  -0.690542879839 Intercept:  637.527685816
# Point one:  (480, 305) Point two:  (960, 619)
# Point one:  (480, 305) Point two:  (0, 637)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.651769519761 Intercept:  -7.80663109832
# Coefficients:  -0.688580879221 Intercept:  636.24054391
# Point one:  (480, 305) Point two:  (960, 617)
# Point one:  (480, 305) Point two:  (0, 636)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  28%|██▊       | 63/222 [00:02<00:07, 22.38it/s]
# Coefficients:  0.643996756703 Intercept:  -2.05542527814
# Coefficients:  -0.684948385574 Intercept:  634.447348691
# Point one:  (478, 306) Point two:  (960, 616)
# Point one:  (478, 306) Point two:  (0, 634)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.645907495151 Intercept:  -3.48969508752
# Coefficients:  -0.695301463115 Intercept:  638.857269878
# Point one:  (478, 305) Point two:  (960, 616)
# Point one:  (478, 305) Point two:  (0, 638)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.644333788422 Intercept:  -1.61803387415
# Coefficients:  -0.681505259173 Intercept:  633.644531046
# Point one:  (479, 307) Point two:  (960, 616)
# Point one:  (479, 307) Point two:  (0, 633)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.66519463616 Intercept:  -14.5446358859
# Coefficients:  -0.698718833327 Intercept:  639.415147933
# Point one:  (479, 304) Point two:  (960, 624)
# Point one:  (479, 304) Point two:  (0, 639)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.654098064286 Intercept:  -6.36017747497
# Coefficients:  -0.665038458138 Intercept:  626.072606312
# Point one:  (479, 307) Point two:  (960, 621)
# Point one:  (479, 307) Point two:  (0, 626)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  30%|██▉       | 66/222 [00:02<00:06, 22.84it/s]
# Coefficients:  0.66250824376 Intercept:  -11.9008780683
# Coefficients:  -0.665473162897 Intercept:  625.428088609
# Point one:  (479, 306) Point two:  (960, 624)
# Point one:  (479, 306) Point two:  (0, 625)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.655895864285 Intercept:  -11.0762244587
# Coefficients:  -0.65925962017 Intercept:  621.502608417
# Point one:  (480, 304) Point two:  (960, 618)
# Point one:  (480, 304) Point two:  (0, 621)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.639759239786 Intercept:  2.11107027353
# Coefficients:  -0.65576207152 Intercept:  620.200962684
# Point one:  (477, 307) Point two:  (960, 616)
# Point one:  (477, 307) Point two:  (0, 620)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  31%|███       | 69/222 [00:02<00:06, 22.87it/s]
# Coefficients:  0.632361200637 Intercept:  7.1326567839
# Coefficients:  -0.685365478229 Intercept:  632.878316626
# Point one:  (474, 307) Point two:  (960, 614)
# Point one:  (474, 307) Point two:  (0, 632)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.64994264381 Intercept:  -4.80974414807
# Coefficients:  -0.693768949941 Intercept:  635.853858053
# Point one:  (476, 305) Point two:  (960, 619)
# Point one:  (476, 305) Point two:  (0, 635)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  32%|███▏      | 72/222 [00:03<00:06, 22.53it/s]
# Coefficients:  0.671236866981 Intercept:  -17.6028837669
# Coefficients:  -0.674982291957 Intercept:  627.893719548
# Point one:  (479, 304) Point two:  (960, 626)
# Point one:  (479, 304) Point two:  (0, 627)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.651337367765 Intercept:  -6.74774795584
# Coefficients:  -0.664069030239 Intercept:  623.729841788
# Point one:  (479, 305) Point two:  (960, 618)
# Point one:  (479, 305) Point two:  (0, 623)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.65436651056 Intercept:  -6.99105973336
# Coefficients:  -0.667959027717 Intercept:  626.082868076
# Point one:  (478, 306) Point two:  (960, 621)
# Point one:  (478, 306) Point two:  (0, 626)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  34%|███▍      | 75/222 [00:03<00:06, 22.60it/s]
# Coefficients:  0.660877043965 Intercept:  -9.83062733334
# Coefficients:  -0.673259551236 Intercept:  627.664129205
# Point one:  (477, 305) Point two:  (960, 624)
# Point one:  (477, 305) Point two:  (0, 627)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.650158862322 Intercept:  -4.16472620596
# Coefficients:  -0.669635396189 Intercept:  626.128477301
# Point one:  (477, 306) Point two:  (960, 619)
# Point one:  (477, 306) Point two:  (0, 626)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  35%|███▌      | 78/222 [00:03<00:06, 23.07it/s]
# Coefficients:  0.636545568441 Intercept:  6.04678384282
# Coefficients:  -0.679718271307 Intercept:  628.818881869
# Point one:  (473, 307) Point two:  (960, 617)
# Point one:  (473, 307) Point two:  (0, 628)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.653204284304 Intercept:  -4.31123806934
# Coefficients:  -0.656534401165 Intercept:  618.604950855
# Point one:  (475, 306) Point two:  (960, 622)
# Point one:  (475, 306) Point two:  (0, 618)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.664969528936 Intercept:  -12.9427432059
# Coefficients:  -0.671316449375 Intercept:  624.919234903
# Point one:  (477, 304) Point two:  (960, 625)
# Point one:  (477, 304) Point two:  (0, 624)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.680325872195 Intercept:  -19.4597497767
# Coefficients:  -0.655665024631 Intercept:  619.390147783
# Point one:  (478, 305) Point two:  (960, 633)
# Point one:  (478, 305) Point two:  (0, 619)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.671794082315 Intercept:  -15.3191128519
# Coefficients:  -0.635525798469 Intercept:  611.101447767
# Point one:  (479, 306) Point two:  (960, 629)
# Point one:  (479, 306) Point two:  (0, 611)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  36%|███▋      | 81/222 [00:03<00:06, 23.28it/s]
# Coefficients:  0.672230175289 Intercept:  -15.5475980261
# Coefficients:  -0.667275252931 Intercept:  622.288563457
# Point one:  (476, 304) Point two:  (960, 629)
# Point one:  (476, 304) Point two:  (0, 622)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.670828863751 Intercept:  -14.8110206116
# Coefficients:  -0.658640428319 Intercept:  620.651278692
# Point one:  (477, 305) Point two:  (960, 629)
# Point one:  (477, 305) Point two:  (0, 620)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.665684223279 Intercept:  -13.4606828486
# Coefficients:  -0.680690146633 Intercept:  627.939770818
# Point one:  (476, 303) Point two:  (960, 625)
# Point one:  (476, 303) Point two:  (0, 627)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  38%|███▊      | 84/222 [00:03<00:05, 23.63it/s]
# Coefficients:  0.670460674887 Intercept:  -17.1048576436
# Coefficients:  -0.664731332146 Intercept:  622.95661026
# Point one:  (479, 304) Point two:  (960, 626)
# Point one:  (479, 304) Point two:  (0, 622)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.668472184232 Intercept:  -13.8755896424
# Coefficients:  -0.65264946381 Intercept:  617.943407843
# Point one:  (478, 305) Point two:  (960, 627)
# Point one:  (478, 305) Point two:  (0, 617)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  39%|███▉      | 87/222 [00:03<00:05, 23.78it/s]
# Coefficients:  0.667456533647 Intercept:  -13.4477954538
# Coefficients:  -0.651728218375 Intercept:  618.658227608
# Point one:  (479, 306) Point two:  (960, 627)
# Point one:  (479, 306) Point two:  (0, 618)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.674465967485 Intercept:  -16.984314439
# Coefficients:  -0.664914965727 Intercept:  622.987753476
# Point one:  (477, 305) Point two:  (960, 630)
# Point one:  (477, 305) Point two:  (0, 622)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.677400487841 Intercept:  -19.1699001057
# Coefficients:  -0.661655741899 Intercept:  622.648942764
# Point one:  (479, 305) Point two:  (960, 631)
# Point one:  (479, 305) Point two:  (0, 622)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  41%|████      | 90/222 [00:03<00:05, 23.99it/s]
# Coefficients:  0.663889683448 Intercept:  -10.6545099161
# Coefficients:  -0.645916667207 Intercept:  616.87249188
# Point one:  (479, 307) Point two:  (960, 626)
# Point one:  (479, 307) Point two:  (0, 616)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.682248118033 Intercept:  -21.8123476711
# Coefficients:  -0.642103400082 Intercept:  614.926639772
# Point one:  (480, 306) Point two:  (960, 633)
# Point one:  (480, 306) Point two:  (0, 614)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  42%|████▏     | 93/222 [00:03<00:05, 24.30it/s]
# Coefficients:  0.685899555019 Intercept:  -21.9489335852
# Coefficients:  -0.650426722925 Intercept:  619.138713244
# Point one:  (479, 307) Point two:  (960, 636)
# Point one:  (479, 307) Point two:  (0, 619)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.688816409728 Intercept:  -24.8422981823
# Coefficients:  -0.645594040305 Intercept:  618.275161013
# Point one:  (481, 307) Point two:  (960, 636)
# Point one:  (481, 307) Point two:  (0, 618)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.696666585344 Intercept:  -29.0249457171
# Coefficients:  -0.659700889114 Intercept:  623.242453465
# Point one:  (480, 305) Point two:  (960, 639)
# Point one:  (480, 305) Point two:  (0, 623)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.692820941512 Intercept:  -28.4893480886
# Coefficients:  -0.656550959935 Intercept:  622.27380717
# Point one:  (482, 305) Point two:  (960, 636)
# Point one:  (482, 305) Point two:  (0, 622)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.681596656226 Intercept:  -22.4647933183
# Coefficients:  -0.662260832776 Intercept:  624.386873208
# Point one:  (481, 305) Point two:  (960, 631)
# Point one:  (481, 305) Point two:  (0, 624)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  43%|████▎     | 96/222 [00:04<00:05, 24.06it/s]
# Coefficients:  0.68083284095 Intercept:  -22.8623817603
# Coefficients:  -0.6569897282 Intercept:  621.858028359
# Point one:  (481, 305) Point two:  (960, 630)
# Point one:  (481, 305) Point two:  (0, 621)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.692608631409 Intercept:  -30.3124538253
# Coefficients:  -0.660056620323 Intercept:  623.090640279
# Point one:  (483, 304) Point two:  (960, 634)
# Point one:  (483, 304) Point two:  (0, 623)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.700032807394 Intercept:  -37.0474429917
# Coefficients:  -0.664690740137 Intercept:  624.888168464
# Point one:  (485, 302) Point two:  (960, 634)
# Point one:  (485, 302) Point two:  (0, 624)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.689336211314 Intercept:  -29.7886129008
# Coefficients:  -0.658462282276 Intercept:  621.597616016
# Point one:  (483, 303) Point two:  (960, 631)
# Point one:  (483, 303) Point two:  (0, 621)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  45%|████▍     | 99/222 [00:04<00:05, 23.54it/s]
# (540, 960, 3)
# Coefficients:  0.701182308926 Intercept:  -39.6685932349
# Coefficients:  -0.652979086452 Intercept:  618.616606858
# Point one:  (486, 301) Point two:  (960, 633)
# Point one:  (486, 301) Point two:  (0, 618)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  46%|████▌     | 102/222 [00:04<00:05, 22.53it/s]
# (540, 960, 3)
# Coefficients:  0.697076522919 Intercept:  -36.7595849344
# Coefficients:  -0.657716839596 Intercept:  621.668611456
# Point one:  (485, 302) Point two:  (960, 632)
# Point one:  (485, 302) Point two:  (0, 621)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.693481797552 Intercept:  -30.122420308
# Coefficients:  -0.66359808749 Intercept:  625.981160351
# Point one:  (483, 305) Point two:  (960, 635)
# Point one:  (483, 305) Point two:  (0, 625)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.688141523369 Intercept:  -26.4783302401
# Coefficients:  -0.677379402331 Intercept:  631.548794817
# Point one:  (481, 305) Point two:  (960, 634)
# Point one:  (481, 305) Point two:  (0, 631)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.688507077826 Intercept:  -26.3169310958
# Coefficients:  -0.670590379311 Intercept:  630.661631558
# Point one:  (483, 306) Point two:  (960, 634)
# Point one:  (483, 306) Point two:  (0, 630)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  49%|████▊     | 108/222 [00:04<00:04, 22.84it/s]
# Coefficients:  0.677653750711 Intercept:  -20.957678103
# Coefficients:  -0.668509129507 Intercept:  628.905294775
# Point one:  (482, 306) Point two:  (960, 629)
# Point one:  (482, 306) Point two:  (0, 628)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.675989718806 Intercept:  -20.7412424057
# Coefficients:  -0.663937212461 Intercept:  627.645655833
# Point one:  (483, 306) Point two:  (960, 628)
# Point one:  (483, 306) Point two:  (0, 627)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.69661361411 Intercept:  -35.2070002493
# Coefficients:  -0.668582825192 Intercept:  628.08771712
# Point one:  (485, 303) Point two:  (960, 633)
# Point one:  (485, 303) Point two:  (0, 628)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.680730734106 Intercept:  -24.6881555742
# Coefficients:  -0.681416009634 Intercept:  633.242989253
# Point one:  (483, 304) Point two:  (960, 628)
# Point one:  (483, 304) Point two:  (0, 633)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.676309475304 Intercept:  -23.5116347503
# Coefficients:  -0.701394770836 Intercept:  640.98290411
# Point one:  (482, 302) Point two:  (960, 625)
# Point one:  (482, 302) Point two:  (0, 640)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  50%|█████     | 111/222 [00:04<00:04, 23.61it/s]
# Coefficients:  0.676733250901 Intercept:  -21.9206004772
# Coefficients:  -0.6871785689 Intercept:  635.43048135
# Point one:  (481, 304) Point two:  (960, 627)
# Point one:  (481, 304) Point two:  (0, 635)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.687408900892 Intercept:  -30.6409270837
# Coefficients:  -0.680947100313 Intercept:  634.358352251
# Point one:  (485, 303) Point two:  (960, 629)
# Point one:  (485, 303) Point two:  (0, 634)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.674552111423 Intercept:  -23.2516484437
# Coefficients:  -0.686473274386 Intercept:  635.868095964
# Point one:  (484, 303) Point two:  (960, 624)
# Point one:  (484, 303) Point two:  (0, 635)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.690654798271 Intercept:  -33.7417154524
# Coefficients:  -0.681928642842 Intercept:  633.303264273
# Point one:  (485, 301) Point two:  (960, 629)
# Point one:  (485, 301) Point two:  (0, 633)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.676755296938 Intercept:  -24.2538272984
# Coefficients:  -0.662020379576 Intercept:  626.311049466
# Point one:  (485, 304) Point two:  (960, 625)
# Point one:  (485, 304) Point two:  (0, 626)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  51%|█████▏    | 114/222 [00:04<00:04, 23.93it/s]
# (540, 960, 3)
# Coefficients:  0.679929001134 Intercept:  -28.6776192049
# Coefficients:  -0.672612900197 Intercept:  629.888461177
# Point one:  (486, 302) Point two:  (960, 624)
# Point one:  (486, 302) Point two:  (0, 629)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  53%|█████▎    | 117/222 [00:04<00:04, 24.03it/s]
# (540, 960, 3)
# Coefficients:  0.674597705443 Intercept:  -24.7906496865
# Coefficients:  -0.65310348248 Intercept:  621.044545657
# Point one:  (486, 303) Point two:  (960, 622)
# Point one:  (486, 303) Point two:  (0, 621)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.679521633422 Intercept:  -26.8150359037
# Coefficients:  -0.65729615451 Intercept:  623.250784386
# Point one:  (486, 303) Point two:  (960, 625)
# Point one:  (486, 303) Point two:  (0, 623)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.673590231099 Intercept:  -24.5142777752
# Coefficients:  -0.66184730616 Intercept:  625.979552447
# Point one:  (487, 303) Point two:  (960, 622)
# Point one:  (487, 303) Point two:  (0, 625)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.660837079643 Intercept:  -16.2033326454
# Coefficients:  -0.667051838633 Intercept:  628.366501221
# Point one:  (485, 304) Point two:  (960, 618)
# Point one:  (485, 304) Point two:  (0, 628)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.663176662759 Intercept:  -16.6117236744
# Coefficients:  -0.667935923016 Intercept:  628.806731588
# Point one:  (484, 304) Point two:  (960, 620)
# Point one:  (484, 304) Point two:  (0, 628)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  55%|█████▌    | 123/222 [00:05<00:04, 24.50it/s]
# (540, 960, 3)
# Coefficients:  0.65344488213 Intercept:  -8.50519210081
# Coefficients:  -0.675658778421 Intercept:  632.724023738
# Point one:  (482, 306) Point two:  (960, 618)
# Point one:  (482, 306) Point two:  (0, 632)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.642122950906 Intercept:  -1.16510918006
# Coefficients:  -0.664392392006 Intercept:  629.861522738
# Point one:  (482, 308) Point two:  (960, 615)
# Point one:  (482, 308) Point two:  (0, 629)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.652189921461 Intercept:  -10.9724740673
# Coefficients:  -0.67579053618 Intercept:  633.497956437
# Point one:  (485, 305) Point two:  (960, 615)
# Point one:  (485, 305) Point two:  (0, 633)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.647609687762 Intercept:  -7.67167337542
# Coefficients:  -0.670560846896 Intercept:  632.019308754
# Point one:  (485, 306) Point two:  (960, 614)
# Point one:  (485, 306) Point two:  (0, 632)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.6516667829 Intercept:  -12.3817502383
# Coefficients:  -0.666517719646 Intercept:  629.764604224
# Point one:  (487, 305) Point two:  (960, 613)
# Point one:  (487, 305) Point two:  (0, 629)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  58%|█████▊    | 129/222 [00:05<00:03, 24.20it/s]
# Coefficients:  0.630002038504 Intercept:  3.98605521027
# Coefficients:  -0.68023875873 Intercept:  635.673461314
# Point one:  (482, 307) Point two:  (960, 608)
# Point one:  (482, 307) Point two:  (0, 635)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.647412929495 Intercept:  -8.67254744343
# Coefficients:  -0.682595967834 Intercept:  636.387531569
# Point one:  (485, 305) Point two:  (960, 612)
# Point one:  (485, 305) Point two:  (0, 636)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.64025750959 Intercept:  -4.64308321276
# Coefficients:  -0.684469865865 Intercept:  637.918513869
# Point one:  (485, 305) Point two:  (960, 610)
# Point one:  (485, 305) Point two:  (0, 637)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.623321359715 Intercept:  6.80958812843
# Coefficients:  -0.679875453926 Intercept:  636.87309209
# Point one:  (483, 308) Point two:  (960, 605)
# Point one:  (483, 308) Point two:  (0, 636)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.627261578142 Intercept:  4.78963372233
# Coefficients:  -0.698065521415 Intercept:  643.807634104
# Point one:  (482, 307) Point two:  (960, 606)
# Point one:  (482, 307) Point two:  (0, 643)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  59%|█████▉    | 132/222 [00:05<00:03, 23.69it/s]
# Coefficients:  0.631705518788 Intercept:  0.798198180078
# Coefficients:  -0.701230504147 Intercept:  646.259552153
# Point one:  (484, 306) Point two:  (960, 607)
# Point one:  (484, 306) Point two:  (0, 646)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.629597235189 Intercept:  2.91599757588
# Coefficients:  -0.704983739079 Intercept:  647.431650585
# Point one:  (482, 306) Point two:  (960, 607)
# Point one:  (482, 306) Point two:  (0, 647)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.625822633092 Intercept:  5.36647224173
# Coefficients:  -0.705031984553 Intercept:  648.243232016
# Point one:  (483, 307) Point two:  (960, 606)
# Point one:  (483, 307) Point two:  (0, 648)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.647917145949 Intercept:  -9.8222054651
# Coefficients:  -0.718746541916 Intercept:  652.965674511
# Point one:  (484, 304) Point two:  (960, 612)
# Point one:  (484, 304) Point two:  (0, 652)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  61%|██████    | 135/222 [00:05<00:03, 24.10it/s]
# Coefficients:  0.633162174061 Intercept:  1.20110924182
# Coefficients:  -0.714927142908 Intercept:  649.139367873
# Point one:  (480, 305) Point two:  (960, 609)
# Point one:  (480, 305) Point two:  (0, 649)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.628068960742 Intercept:  1.09741743405
# Coefficients:  -0.713889362024 Intercept:  647.742748096
# Point one:  (481, 303) Point two:  (960, 604)
# Point one:  (481, 303) Point two:  (0, 647)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  62%|██████▏   | 138/222 [00:05<00:03, 24.41it/s]
# (540, 960, 3)
# Coefficients:  0.628544073285 Intercept:  -0.744788233653
# Coefficients:  -0.696805603745 Intercept:  640.7390953
# Point one:  (484, 303) Point two:  (960, 602)
# Point one:  (484, 303) Point two:  (0, 640)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.61566385002 Intercept:  10.1170615548
# Coefficients:  -0.70248671933 Intercept:  643.659253131
# Point one:  (480, 306) Point two:  (960, 601)
# Point one:  (480, 306) Point two:  (0, 643)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.616348629164 Intercept:  8.49156651151
# Coefficients:  -0.687161072842 Intercept:  638.16334457
# Point one:  (483, 306) Point two:  (960, 600)
# Point one:  (483, 306) Point two:  (0, 638)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.62766962532 Intercept:  2.21250093235
# Coefficients:  -0.704194813305 Intercept:  646.745692811
# Point one:  (483, 305) Point two:  (960, 604)
# Point one:  (483, 305) Point two:  (0, 646)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  64%|██████▎   | 141/222 [00:05<00:03, 24.45it/s]
# (540, 960, 3)
# Coefficients:  0.630939316344 Intercept:  2.06319351299
# Coefficients:  -0.719574684279 Intercept:  653.160937727
# Point one:  (482, 306) Point two:  (960, 607)
# Point one:  (482, 306) Point two:  (0, 653)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  65%|██████▍   | 144/222 [00:06<00:03, 24.50it/s]
# Coefficients:  0.629622474931 Intercept:  3.71815548556
# Coefficients:  -0.710266943432 Intercept:  650.540675366
# Point one:  (482, 307) Point two:  (960, 608)
# Point one:  (482, 307) Point two:  (0, 650)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.633384324357 Intercept:  2.40355910006
# Coefficients:  -0.707754988732 Intercept:  650.660202815
# Point one:  (483, 308) Point two:  (960, 610)
# Point one:  (483, 308) Point two:  (0, 650)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.639803206468 Intercept:  -1.73766907822
# Coefficients:  -0.727320761928 Intercept:  658.176235278
# Point one:  (482, 307) Point two:  (960, 612)
# Point one:  (482, 307) Point two:  (0, 658)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.634887470192 Intercept:  -0.961241710047
# Coefficients:  -0.717579740442 Intercept:  654.326400741
# Point one:  (484, 306) Point two:  (960, 608)
# Point one:  (484, 306) Point two:  (0, 654)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.628060259266 Intercept:  0.853424414974
# Coefficients:  -0.713858752626 Intercept:  652.443783479
# Point one:  (485, 305) Point two:  (960, 603)
# Point one:  (485, 305) Point two:  (0, 652)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  66%|██████▌   | 147/222 [00:06<00:03, 23.85it/s]
# Coefficients:  0.628725154045 Intercept:  0.820087938813
# Coefficients:  -0.729731884697 Intercept:  657.754098945
# Point one:  (483, 304) Point two:  (960, 604)
# Point one:  (483, 304) Point two:  (0, 657)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.632726650896 Intercept:  -3.08046626956
# Coefficients:  -0.71793791505 Intercept:  651.839133456
# Point one:  (484, 303) Point two:  (960, 604)
# Point one:  (484, 303) Point two:  (0, 651)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.609848015725 Intercept:  12.1199758685
# Coefficients:  -0.717217614986 Intercept:  652.425938051
# Point one:  (482, 306) Point two:  (960, 597)
# Point one:  (482, 306) Point two:  (0, 652)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  68%|██████▊   | 150/222 [00:06<00:03, 23.17it/s]
# Coefficients:  0.624838607135 Intercept:  3.16374360806
# Coefficients:  -0.721752120849 Intercept:  654.65833967
# Point one:  (483, 305) Point two:  (960, 603)
# Point one:  (483, 305) Point two:  (0, 654)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.617101052978 Intercept:  7.5533826298
# Coefficients:  -0.732185345991 Intercept:  659.066389482
# Point one:  (482, 305) Point two:  (960, 599)
# Point one:  (482, 305) Point two:  (0, 659)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  69%|██████▉   | 153/222 [00:06<00:02, 23.47it/s]
# (540, 960, 3)
# Coefficients:  0.636203905274 Intercept:  -4.55679444819
# Coefficients:  -0.743074472677 Intercept:  665.051950758
# Point one:  (485, 304) Point two:  (960, 606)
# Point one:  (485, 304) Point two:  (0, 665)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.643513709161 Intercept:  -10.5532273809
# Coefficients:  -0.726358624932 Intercept:  657.088721698
# Point one:  (487, 303) Point two:  (960, 607)
# Point one:  (487, 303) Point two:  (0, 657)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.62477118503 Intercept:  0.695009522401
# Coefficients:  -0.713780702113 Intercept:  652.168268305
# Point one:  (486, 304) Point two:  (960, 600)
# Point one:  (486, 304) Point two:  (0, 652)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.620244408577 Intercept:  2.96241641688
# Coefficients:  -0.720950485195 Intercept:  654.693580493
# Point one:  (485, 304) Point two:  (960, 598)
# Point one:  (485, 304) Point two:  (0, 654)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.643347692817 Intercept:  -11.234802419
# Coefficients:  -0.728901516517 Intercept:  656.47423581
# Point one:  (486, 301) Point two:  (960, 606)
# Point one:  (486, 301) Point two:  (0, 656)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  72%|███████▏  | 159/222 [00:06<00:02, 23.55it/s]
# (540, 960, 3)
# Coefficients:  0.634135485559 Intercept:  -7.90397611655
# Coefficients:  -0.731526500599 Intercept:  658.564105598
# Point one:  (488, 301) Point two:  (960, 600)
# Point one:  (488, 301) Point two:  (0, 658)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.617174507337 Intercept:  4.53370852595
# Coefficients:  -0.715692006502 Intercept:  652.338531078
# Point one:  (486, 304) Point two:  (960, 597)
# Point one:  (486, 304) Point two:  (0, 652)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.623461159657 Intercept:  0.56735376821
# Coefficients:  -0.724369327272 Intercept:  655.600712979
# Point one:  (485, 303) Point two:  (960, 599)
# Point one:  (485, 303) Point two:  (0, 655)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.613710458261 Intercept:  6.37134610435
# Coefficients:  -0.734383214059 Intercept:  661.138619675
# Point one:  (485, 304) Point two:  (960, 595)
# Point one:  (485, 304) Point two:  (0, 661)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.616966364755 Intercept:  1.15846813107
# Coefficients:  -0.739837952141 Intercept:  663.629696891
# Point one:  (488, 302) Point two:  (960, 593)
# Point one:  (488, 302) Point two:  (0, 663)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  73%|███████▎  | 162/222 [00:06<00:02, 23.66it/s]
# (540, 960, 3)
# Coefficients:  0.60172392558 Intercept:  12.0456791376
# Coefficients:  -0.740685543964 Intercept:  665.424366617
# Point one:  (486, 304) Point two:  (960, 589)
# Point one:  (486, 304) Point two:  (0, 665)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.607146359038 Intercept:  6.64320020006
# Coefficients:  -0.75612043953 Intercept:  671.497273331
# Point one:  (487, 302) Point two:  (960, 589)
# Point one:  (487, 302) Point two:  (0, 671)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.594348487895 Intercept:  17.3688646591
# Coefficients:  -0.758147623341 Intercept:  673.259693417
# Point one:  (484, 305) Point two:  (960, 587)
# Point one:  (484, 305) Point two:  (0, 673)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  74%|███████▍  | 165/222 [00:06<00:02, 23.92it/s]
# Coefficients:  0.584611668076 Intercept:  26.2906493193
# Coefficients:  -0.754907217109 Intercept:  672.43348822
# Point one:  (482, 308) Point two:  (960, 587)
# Point one:  (482, 308) Point two:  (0, 672)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.582051697563 Intercept:  27.0836703084
# Coefficients:  -0.751615932389 Intercept:  672.460853744
# Point one:  (483, 308) Point two:  (960, 585)
# Point one:  (483, 308) Point two:  (0, 672)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  76%|███████▌  | 168/222 [00:07<00:02, 24.06it/s]
# (540, 960, 3)
# Coefficients:  0.588298627459 Intercept:  24.3241268961
# Coefficients:  -0.760150913334 Intercept:  674.438790176
# Point one:  (482, 307) Point two:  (960, 589)
# Point one:  (482, 307) Point two:  (0, 674)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.573017163366 Intercept:  33.7760479777
# Coefficients:  -0.765675620994 Intercept:  676.817480273
# Point one:  (480, 309) Point two:  (960, 583)
# Point one:  (480, 309) Point two:  (0, 676)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.578650962841 Intercept:  29.3034177412
# Coefficients:  -0.755834520981 Intercept:  673.241288235
# Point one:  (482, 308) Point two:  (960, 584)
# Point one:  (482, 308) Point two:  (0, 673)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  77%|███████▋  | 171/222 [00:07<00:02, 24.26it/s]
# Coefficients:  0.580417395651 Intercept:  30.1406835791
# Coefficients:  -0.769207168603 Intercept:  678.093975441
# Point one:  (480, 308) Point two:  (960, 587)
# Point one:  (480, 308) Point two:  (0, 678)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.574689566871 Intercept:  34.0935579917
# Coefficients:  -0.773728608549 Intercept:  680.382324063
# Point one:  (479, 309) Point two:  (960, 585)
# Point one:  (479, 309) Point two:  (0, 680)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  78%|███████▊  | 174/222 [00:07<00:01, 24.10it/s]
# Coefficients:  0.578370047929 Intercept:  30.5625873438
# Coefficients:  -0.76733460153 Intercept:  677.248660245
# Point one:  (480, 308) Point two:  (960, 585)
# Point one:  (480, 308) Point two:  (0, 677)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.590947291097 Intercept:  23.7445482672
# Coefficients:  -0.776759673979 Intercept:  681.567843636
# Point one:  (480, 307) Point two:  (960, 591)
# Point one:  (480, 307) Point two:  (0, 681)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.59013478297 Intercept:  22.8353131018
# Coefficients:  -0.799449783916 Intercept:  690.38527792
# Point one:  (480, 306) Point two:  (960, 589)
# Point one:  (480, 306) Point two:  (0, 690)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.581291604405 Intercept:  29.9308860296
# Coefficients:  -0.783370352487 Intercept:  684.128550735
# Point one:  (479, 308) Point two:  (960, 587)
# Point one:  (479, 308) Point two:  (0, 684)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.591300274042 Intercept:  22.8602665813
# Coefficients:  -0.768582378364 Intercept:  677.633498728
# Point one:  (481, 307) Point two:  (960, 590)
# Point one:  (481, 307) Point two:  (0, 677)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.582111430577 Intercept:  30.6674533786
# Coefficients:  -0.776554984438 Intercept:  681.866682778
# Point one:  (479, 309) Point two:  (960, 589)
# Point one:  (479, 309) Point two:  (0, 681)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  80%|███████▉  | 177/222 [00:07<00:01, 24.49it/s]
# (540, 960, 3)
# Coefficients:  0.582325531341 Intercept:  28.3725949251
# Coefficients:  -0.772321951906 Intercept:  680.49733895
# Point one:  (481, 308) Point two:  (960, 587)
# Point one:  (481, 308) Point two:  (0, 680)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.605349530159 Intercept:  12.3744785557
# Coefficients:  -0.794436040001 Intercept:  689.599504247
# Point one:  (483, 305) Point two:  (960, 593)
# Point one:  (483, 305) Point two:  (0, 689)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.584340312209 Intercept:  24.2345192501
# Coefficients:  -0.809567230974 Intercept:  694.866299927
# Point one:  (481, 305) Point two:  (960, 585)
# Point one:  (481, 305) Point two:  (0, 694)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  81%|████████  | 180/222 [00:07<00:01, 24.90it/s]
# (540, 960, 3)
# Coefficients:  0.600738257752 Intercept:  12.8394162802
# Coefficients:  -0.808282175052 Intercept:  694.276231489
# Point one:  (483, 303) Point two:  (960, 589)
# Point one:  (483, 303) Point two:  (0, 694)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.588068052303 Intercept:  22.4850363678
# Coefficients:  -0.798941168529 Intercept:  690.646049836
# Point one:  (481, 305) Point two:  (960, 587)
# Point one:  (481, 305) Point two:  (0, 690)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  82%|████████▏ | 183/222 [00:07<00:01, 24.99it/s]
# Coefficients:  0.582929980533 Intercept:  25.0514961744
# Coefficients:  -0.792481114684 Intercept:  687.57440701
# Point one:  (481, 305) Point two:  (960, 584)
# Point one:  (481, 305) Point two:  (0, 687)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.589549215965 Intercept:  24.2565740588
# Coefficients:  -0.787134711992 Intercept:  685.303516504
# Point one:  (480, 307) Point two:  (960, 590)
# Point one:  (480, 307) Point two:  (0, 685)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.577224206469 Intercept:  29.8619165809
# Coefficients:  -0.785391035566 Intercept:  684.364844673
# Point one:  (480, 307) Point two:  (960, 583)
# Point one:  (480, 307) Point two:  (0, 684)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  84%|████████▍ | 186/222 [00:07<00:01, 25.08it/s]
# Coefficients:  0.597420792672 Intercept:  14.9063473304
# Coefficients:  -0.799852848434 Intercept:  689.272755939
# Point one:  (482, 303) Point two:  (960, 588)
# Point one:  (482, 303) Point two:  (0, 689)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.591019675706 Intercept:  21.7095851512
# Coefficients:  -0.798941756036 Intercept:  689.31126969
# Point one:  (480, 305) Point two:  (960, 589)
# Point one:  (480, 305) Point two:  (0, 689)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.585609683634 Intercept:  22.3736828037
# Coefficients:  -0.785109386027 Intercept:  682.611150318
# Point one:  (481, 304) Point two:  (960, 584)
# Point one:  (481, 304) Point two:  (0, 682)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  85%|████████▌ | 189/222 [00:07<00:01, 25.35it/s]
# (540, 960, 3)
# Coefficients:  0.575918391199 Intercept:  25.8092872744
# Coefficients:  -0.770588906642 Intercept:  674.771832915
# Point one:  (481, 303) Point two:  (960, 578)
# Point one:  (481, 303) Point two:  (0, 674)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.570451392662 Intercept:  27.8463628402
# Coefficients:  -0.773931867811 Intercept:  673.867230426
# Point one:  (480, 301) Point two:  (960, 575)
# Point one:  (480, 301) Point two:  (0, 673)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.564526323066 Intercept:  33.4222751109
# Coefficients:  -0.792775437925 Intercept:  683.512982196
# Point one:  (478, 303) Point two:  (960, 575)
# Point one:  (478, 303) Point two:  (0, 683)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  86%|████████▋ | 192/222 [00:08<00:01, 25.43it/s]
# (540, 960, 3)
# Coefficients:  0.560998223373 Intercept:  36.6120525458
# Coefficients:  -0.780622303855 Intercept:  680.196932293
# Point one:  (479, 305) Point two:  (960, 575)
# Point one:  (479, 305) Point two:  (0, 680)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.558590816009 Intercept:  40.4647630605
# Coefficients:  -0.796548915226 Intercept:  690.201529354
# Point one:  (479, 308) Point two:  (960, 576)
# Point one:  (479, 308) Point two:  (0, 690)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  88%|████████▊ | 195/222 [00:08<00:01, 25.38it/s]
# Coefficients:  0.579588815726 Intercept:  27.6294106819
# Coefficients:  -0.78283237509 Intercept:  685.439097226
# Point one:  (482, 307) Point two:  (960, 584)
# Point one:  (482, 307) Point two:  (0, 685)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.580285359528 Intercept:  26.511726319
# Coefficients:  -0.775167660862 Intercept:  682.308868621
# Point one:  (483, 307) Point two:  (960, 583)
# Point one:  (483, 307) Point two:  (0, 682)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.585912220744 Intercept:  24.5284785939
# Coefficients:  -0.779668437055 Intercept:  684.068289843
# Point one:  (482, 307) Point two:  (960, 587)
# Point one:  (482, 307) Point two:  (0, 684)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  89%|████████▉ | 198/222 [00:08<00:00, 25.49it/s]
# Coefficients:  0.589682564522 Intercept:  19.9897302441
# Coefficients:  -0.790629632229 Intercept:  686.373837563
# Point one:  (482, 304) Point two:  (960, 586)
# Point one:  (482, 304) Point two:  (0, 686)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.576125363617 Intercept:  29.6512338324
# Coefficients:  -0.764235707605 Intercept:  675.287888665
# Point one:  (481, 307) Point two:  (960, 582)
# Point one:  (481, 307) Point two:  (0, 675)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.574296195674 Intercept:  31.4003440731
# Coefficients:  -0.78519109923 Intercept:  683.134547673
# Point one:  (479, 306) Point two:  (960, 582)
# Point one:  (479, 306) Point two:  (0, 683)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  91%|█████████ | 201/222 [00:08<00:00, 25.32it/s]
# (540, 960, 3)
# Coefficients:  0.581668408864 Intercept:  26.821029227
# Coefficients:  -0.754919508607 Intercept:  671.204476288
# Point one:  (482, 307) Point two:  (960, 585)
# Point one:  (482, 307) Point two:  (0, 671)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.564967688156 Intercept:  37.2418099716
# Coefficients:  -0.831187147803 Intercept:  705.086012371
# Point one:  (478, 307) Point two:  (960, 579)
# Point one:  (478, 307) Point two:  (0, 705)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  -0.00328820475509 Intercept:  480.88675291
# Coefficients:  -0.826507306266 Intercept:  703.239448234
# Point one:  (270, 479) Point two:  (0, 480)
# Point one:  (270, 479) Point two:  (0, 703)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.589241461702 Intercept:  19.9197468579
# Coefficients:  -0.794911425514 Intercept:  687.790155748
# Point one:  (482, 304) Point two:  (960, 585)
# Point one:  (482, 304) Point two:  (0, 687)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.561878000873 Intercept:  38.9050360105
# Coefficients:  -0.79979145816 Intercept:  689.272683113
# Point one:  (477, 307) Point two:  (960, 578)
# Point one:  (477, 307) Point two:  (0, 689)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  93%|█████████▎| 207/222 [00:08<00:00, 25.30it/s]
# (540, 960, 3)
# Coefficients:  0.590227831038 Intercept:  15.8898779698
# Coefficients:  -0.806533407555 Intercept:  691.014926961
# Point one:  (483, 301) Point two:  (960, 582)
# Point one:  (483, 301) Point two:  (0, 691)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.565917403583 Intercept:  32.9564794666
# Coefficients:  -0.78847419673 Intercept:  684.2615644
# Point one:  (480, 305) Point two:  (960, 576)
# Point one:  (480, 305) Point two:  (0, 684)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.566857316513 Intercept:  33.3536762433
# Coefficients:  -0.78499425645 Intercept:  680.885669974
# Point one:  (478, 304) Point two:  (960, 577)
# Point one:  (478, 304) Point two:  (0, 680)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.551748531463 Intercept:  43.1834540102
# Coefficients:  -0.795483390895 Intercept:  685.840538056
# Point one:  (477, 306) Point two:  (960, 572)
# Point one:  (477, 306) Point two:  (0, 685)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.573648066084 Intercept:  26.8778732008
# Coefficients:  -0.772360678877 Intercept:  676.145047872
# Point one:  (482, 303) Point two:  (960, 577)
# Point one:  (482, 303) Point two:  (0, 676)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  95%|█████████▍| 210/222 [00:08<00:00, 25.28it/s]
# Coefficients:  0.563065538523 Intercept:  34.7967467527
# Coefficients:  -0.737226864471 Intercept:  662.015755843
# Point one:  (482, 306) Point two:  (960, 575)
# Point one:  (482, 306) Point two:  (0, 662)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.560870763706 Intercept:  33.6719065464
# Coefficients:  -0.715610590125 Intercept:  654.070099995
# Point one:  (486, 306) Point two:  (960, 572)
# Point one:  (486, 306) Point two:  (0, 654)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.566722005783 Intercept:  31.9021554969
# Coefficients:  -0.776595970083 Intercept:  680.245837659
# Point one:  (482, 305) Point two:  (960, 575)
# Point one:  (482, 305) Point two:  (0, 680)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.552241732386 Intercept:  41.8678227528
# Coefficients:  -0.781571412454 Intercept:  682.408148268
# Point one:  (480, 307) Point two:  (960, 572)
# Point one:  (480, 307) Point two:  (0, 682)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  96%|█████████▌| 213/222 [00:08<00:00, 25.45it/s]
# (540, 960, 3)
# Coefficients:  0.569328163428 Intercept:  33.418805025
# Coefficients:  -0.765940977624 Intercept:  675.93104583
# Point one:  (481, 307) Point two:  (960, 579)
# Point one:  (481, 307) Point two:  (0, 675)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.562319374167 Intercept:  37.9325701569
# Coefficients:  -0.783806563098 Intercept:  683.932784997
# Point one:  (479, 307) Point two:  (960, 577)
# Point one:  (479, 307) Point two:  (0, 683)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
#  97%|█████████▋| 216/222 [00:09<00:00, 25.59it/s]
# (540, 960, 3)
# Coefficients:  0.562941210927 Intercept:  37.5588571759
# Coefficients:  -0.767662136544 Intercept:  678.625617441
# Point one:  (481, 308) Point two:  (960, 577)
# Point one:  (481, 308) Point two:  (0, 678)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.563820777376 Intercept:  37.5051899715
# Coefficients:  -0.781838803232 Intercept:  683.94934706
# Point one:  (480, 308) Point two:  (960, 578)
# Point one:  (480, 308) Point two:  (0, 683)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.561884434693 Intercept:  39.8317494575
# Coefficients:  -0.768420542013 Intercept:  678.029293385
# Point one:  (479, 309) Point two:  (960, 579)
# Point one:  (479, 309) Point two:  (0, 678)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#  99%|█████████▊| 219/222 [00:09<00:00, 25.69it/s]
# Coefficients:  0.559341110548 Intercept:  41.8368620631
# Coefficients:  -0.771049863589 Intercept:  679.109786416
# Point one:  (479, 309) Point two:  (960, 578)
# Point one:  (479, 309) Point two:  (0, 679)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.569151805547 Intercept:  36.5957891731
# Coefficients:  -0.780934581631 Intercept:  682.494907242
# Point one:  (478, 308) Point two:  (960, 582)
# Point one:  (478, 308) Point two:  (0, 682)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# 100%|█████████▉| 221/222 [00:09<00:00, 23.99it/s]
# Coefficients:  0.571918955124 Intercept:  33.9734594776
# Coefficients:  -0.769796809882 Intercept:  677.611483422
# Point one:  (479, 308) Point two:  (960, 583)
# Point one:  (479, 308) Point two:  (0, 677)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: white.mp4
#
# CPU times: user 8.88 s, sys: 2.41 s, total: 11.3 s
# Wall time: 9.6 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="white.mp4">
# </video>

# %% [markdown]
# **At this point, if you were successful you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform.  Modify your draw_lines function accordingly and try re-running your pipeline.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'yellow.mp4'
clip2 = VideoFileClip('solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)
# Out:
# Coefficients:  0.658443533492 Intercept:  -10.352763292
# Coefficients:  -0.615688531362 Intercept:  608.849963928
# Point one:  (485, 309) Point two:  (960, 621)
# Point one:  (485, 309) Point two:  (0, 608)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# [MoviePy] >>>> Building video yellow.mp4
# [MoviePy] Writing video yellow.mp4
#   0%|          | 0/682 [00:00<?, ?it/s]
#   0%|          | 3/682 [00:00<00:28, 23.55it/s]
# Coefficients:  0.658443533492 Intercept:  -10.352763292
# Coefficients:  -0.615688531362 Intercept:  608.849963928
# Point one:  (485, 309) Point two:  (960, 621)
# Point one:  (485, 309) Point two:  (0, 608)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.657406582529 Intercept:  -9.49542687454
# Coefficients:  -0.616529283122 Intercept:  610.654641801
# Point one:  (486, 310) Point two:  (960, 621)
# Point one:  (486, 310) Point two:  (0, 610)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.675036158355 Intercept:  -21.4748872793
# Coefficients:  -0.62080176225 Intercept:  611.178084544
# Point one:  (488, 308) Point two:  (960, 626)
# Point one:  (488, 308) Point two:  (0, 611)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.66313051717 Intercept:  -13.9901137952
# Coefficients:  -0.62757551038 Intercept:  614.975341273
# Point one:  (487, 309) Point two:  (960, 622)
# Point one:  (487, 309) Point two:  (0, 614)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.528583992964 Intercept:  92.2326297274
# Coefficients:  -0.634893368769 Intercept:  616.938484475
# Point one:  (450, 330) Point two:  (960, 599)
# Point one:  (450, 330) Point two:  (0, 616)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#   1%|          | 6/682 [00:00<00:28, 23.47it/s]
#   1%|▏         | 9/682 [00:00<00:28, 23.68it/s]
# Coefficients:  0.64 Intercept:  -0.88
# Coefficients:  -0.6393002813 Intercept:  619.887390649
# Point one:  (485, 309) Point two:  (960, 613)
# Point one:  (485, 309) Point two:  (0, 619)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.616666666667 Intercept:  11.5
# Coefficients:  -0.649452344207 Intercept:  624.343190638
# Point one:  (484, 309) Point two:  (960, 603)
# Point one:  (484, 309) Point two:  (0, 624)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.702869440459 Intercept:  -39.337446198
# Coefficients:  -0.642681749049 Intercept:  621.020679917
# Point one:  (490, 305) Point two:  (960, 635)
# Point one:  (490, 305) Point two:  (0, 621)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.647003214218 Intercept:  -7.36226129703
# Coefficients:  -0.649909653646 Intercept:  623.874007645
# Point one:  (486, 307) Point two:  (960, 613)
# Point one:  (486, 307) Point two:  (0, 623)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.680013931619 Intercept:  -28.1187786614
# Coefficients:  -0.658595195982 Intercept:  626.444917455
# Point one:  (488, 304) Point two:  (960, 624)
# Point one:  (488, 304) Point two:  (0, 626)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#   2%|▏         | 12/682 [00:00<00:28, 23.48it/s]
# Coefficients:  0.630144483363 Intercept:  2.57558012259
# Coefficients:  -0.658316480513 Intercept:  627.529665502
# Point one:  (485, 308) Point two:  (960, 607)
# Point one:  (485, 308) Point two:  (0, 627)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.671665545026 Intercept:  -24.2766056131
# Coefficients:  -0.654993792958 Intercept:  625.716034933
# Point one:  (489, 304) Point two:  (960, 620)
# Point one:  (489, 304) Point two:  (0, 625)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.64154487853 Intercept:  -4.41579902569
# Coefficients:  -0.662235505529 Intercept:  627.61544328
# Point one:  (484, 306) Point two:  (960, 611)
# Point one:  (484, 306) Point two:  (0, 627)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.647522531831 Intercept:  -8.56041506512
# Coefficients:  -0.66490969109 Intercept:  629.439107017
# Point one:  (486, 306) Point two:  (960, 613)
# Point one:  (486, 306) Point two:  (0, 629)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
#   2%|▏         | 15/682 [00:00<00:27, 23.98it/s]
# Coefficients:  0.636834110499 Intercept:  -1.31831990957
# Coefficients:  -0.684007619619 Intercept:  637.553397922
# Point one:  (483, 306) Point two:  (960, 610)
# Point one:  (483, 306) Point two:  (0, 637)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.630493819091 Intercept:  0.592976727929
# Coefficients:  -0.680964918061 Intercept:  636.311257242
# Point one:  (484, 306) Point two:  (960, 605)
# Point one:  (484, 306) Point two:  (0, 636)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# Coefficients:  0.624288700721 Intercept:  6.94380716583
# Coefficients:  -0.67714739957 Intercept:  634.09392386
# Point one:  (481, 307) Point two:  (960, 606)
# Point one:  (481, 307) Point two:  (0, 634)
# hough_rgb.shape:  (540, 960, 3)
# hough_rgb.type:  uint8
# (540, 960, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-07316aa468bc> in <module>()
#       2 clip2 = VideoFileClip('solidYellowLeft.mp4')
#       3 yellow_clip = clip2.fl_image(process_image)
# ----> 4 get_ipython().magic('time yellow_clip.write_videofile(yellow_output, audio=False)')
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2161         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2162         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2163         return self.run_line_magic(magic_name, magic_arg_s)
#    2164
#    2165     #-------------------------------------------------------------------------
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2082                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2083             with self.builtin_trap:
# -> 2084                 result = fn(*args,**kwargs)
#    2085             return result
#    2086
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1171         if mode=='eval':
#    1172             st = clock2()
# -> 1173             out = eval(code, glob, local_ns)
#    1174             end = clock2()
#    1175         else:
#
# <timed eval> in <module>()
#
# <decorator-gen-174> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# <decorator-gen-173> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     135              for (k,v) in k.items()}
#     136
# --> 137     return f(clip, *new_a, **new_kw)
#
# <decorator-gen-172> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/video/VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#     337                            audiofile = audiofile,
#     338                            verbose=verbose, threads=threads,
# --> 339                            ffmpeg_params=ffmpeg_params)
#     340
#     341         if remove_temp and make_audio:
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/video/io/ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params)
#     202
#     203     for t,frame in clip.iter_frames(progress_bar=True, with_times=True,
# --> 204                                     fps=fps, dtype="uint8"):
#     205         if withmask:
#     206             mask = (255*clip.mask.get_frame(t))
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/tqdm/_tqdm.py in __iter__(self)
#     711 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     712
# --> 713             for obj in iterable:
#     714                 yield obj
#     715                 # Update and print the progressbar.
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/Clip.py in generator()
#     471             for t in np.arange(0, self.duration, 1.0/fps):
#     472
# --> 473                 frame = self.get_frame(t)
#     474
#     475                 if (dtype is not None) and (frame.dtype != dtype):
#
# <decorator-gen-137> in get_frame(self, t)
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/Clip.py in get_frame(self, t)
#      93                 return frame
#      94         else:
# ---> 95             return self.make_frame(t)
#      96
#      97     def fl(self, fun, apply_to=[] , keep_duration=True):
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/Clip.py in <lambda>(t)
#     134
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#     138         if not keep_duration:
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/moviepy/video/VideoClip.py in <lambda>(gf, t)
#     512         `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     513         """
# --> 514         return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#     515
#     516     # --------------------------------------------------------------
#
# <ipython-input-123-57764b8ad4d8> in process_image(image)
#       3     # TODO: put your pipeline here,
#       4     # you should return the final output (image with lines are drawn on lanes)
# ----> 5     result = draw_lane_lines(image)
#       6     print(result.shape)
#       7     return result
#
# <ipython-input-125-a1a6c90213f8> in draw_lane_lines(image)
#      33     min_line_len = 20 #minimum number of pixels making up a line
#      34     max_line_gap = 40    # maximum gap in pixels between connectable line segments
# ---> 35     lines_image = hough_lines(edges_image_with_mask, rho, theta, threshold, min_line_len, max_line_gap)
#      36     # print("Hough output image.shape: ", lines_image.shape)
#      37     # plt.imshow(lines_image)
#
# <ipython-input-41-1277c96849a8> in hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap)
#      50     # print("Hough lines: ", lines)
#      51     line_img = np.zeros(img.shape, dtype=np.uint8)
# ---> 52     draw_lines(line_img, lines)
#      53     return line_img
#      54
#
# <ipython-input-114-674ed93b84bb> in draw_lines(img, lines, color, thickness)
#      46
#      47     # Get intercept and coefficient regression lines
# ---> 48     pos_coef, pos_intercept = find_linear_regression_line(positive_slope_points)
#      49     neg_coef, neg_intercept = find_linear_regression_line(negative_slope_points)
#      50
#
# <ipython-input-111-858bb9bd8ea1> in find_linear_regression_line(points)
#       9
#      10     # Fit points to LinearRegression line
# ---> 11     clf = LinearRegression().fit(points_x, points_y)
#      12
#      13     # Get parameters from line
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     510         n_jobs_ = self.n_jobs
#     511         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 512                          y_numeric=True, multi_output=True)
#     513
#     514         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# --> 521                     ensure_min_features, warn_on_dtype, estimator)
#     522     if multi_output:
#     523         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /Users/jessica/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     422                              " a minimum of %d is required%s."
#     423                              % (n_features, shape_repr, ensure_min_features,
# --> 424                                 context))
#     425
#     426     if warn_on_dtype and dtype_orig is not None and array.dtype != dtype_orig:
#
# ValueError: Found array with 0 feature(s) (shape=(1, 0)) while a minimum of 1 is required.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="yellow.mp4">
# </video>

# %% [markdown]
# ## Reflections
#
# Congratulations on finding the lane lines!  As the final step in this project, we would like you to share your thoughts on your lane finding pipeline... specifically, how could you imagine making your algorithm better / more robust?  Where will your current algorithm be likely to fail?
#
# Please add your thoughts below,  and if you're up for making your pipeline more robust, be sure to scroll down and check out the optional challenge video below!

# %% [markdown]
# ## Submission
#
# If you're satisfied with your video outputs it's time to submit!

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'extra.mp4'
clip2 = VideoFileClip('challenge.mp4')
challenge_clip = clip2.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
