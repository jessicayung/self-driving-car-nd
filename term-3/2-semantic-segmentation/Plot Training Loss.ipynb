# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
training_losses = [0.1369, 0.1009, 0.2024, 0.0947, 0.0713, 
0.1178, 0.0611, 0.0209, 0.0218, 0.0180, 
0.0543, 0.0291, 0.0388, 0.0148, 0.0317, 
0.0159, 0.0308, 0.0111, 0.0344, 0.0200]

# %%
plt.plot(training_losses)
plt.title("Training Loss for a Fully Convolutional Network for Semantic Segmentation")
plt.xlabel("Epochs")
plt.xticks([-1,4,9,14,19],[0,5,10,15,20])
plt.ylabel("Training Loss")
